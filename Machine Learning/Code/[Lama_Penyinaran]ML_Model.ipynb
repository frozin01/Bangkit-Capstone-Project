# %% [markdown]
# <a href="https://colab.research.google.com/github/u1-byte/SmartCropYieldsPrediction/blob/main/Machine%20Learning/Code/%5BLama_Penyinaran%5DML_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import library
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from google.colab import files
import csv
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
# Upload file dataset dari lokal
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5445a272-0d35-4cb0-a619-e3a6308b1852" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5445a272-0d35-4cb0-a619-e3a6308b1852">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Cuaca.csv to Cuaca.csv

# %% [markdown]
# # **Provinsi Jatim**

# %%
# Input data Jatim
input_lama_penyinaran_ratarata = []
number_of_input = []
number=1

# Baca file.csv
with open('/content/Cuaca.csv') as csv_file:
  csv_reader = csv.reader(csv_file, delimiter=',')
  next(csv_reader)
  for row in csv_reader:
    number_of_input.append(number)
    input_lama_penyinaran_ratarata.append(float(row[4]))
    number+=1

# %%
# Grafik garis dari Suhu
plt.plot(number_of_input,input_lama_penyinaran_ratarata,marker='o')
plt.title('Lama Penyinaran (2015 - 2020)')
plt.ylabel('Jam')
plt.xlabel('Bulan')
plt.show()

# %%
# Input dari data pada database
dataset = []
counter=0

# Baca file.csv
with open('/content/Cuaca.csv') as csv_file:
  csv_reader = csv.reader(csv_file, delimiter=',')
  next(csv_reader)
  for row in csv_reader:
    dataset.append([])
    dataset[counter].append(float(row[4]))
    counter+=1

dataset = np.array(dataset)

print(dataset)
# Out:
# [[4.82]
#  [6.25]
#  [5.39]
#  [5.59]
#  [8.27]
#  [8.61]
#  [8.49]
#  [9.07]
#  [9.31]
#  [9.12]
#  [8.51]
#  [5.38]
#  [6.37]
#  [4.62]
#  [5.41]
#  [6.13]
#  [7.17]
#  [6.3 ]
#  [6.84]
#  [8.03]
#  [7.93]
#  [5.67]
#  [6.05]
#  [3.99]
#  [4.13]
#  [4.36]
#  [4.75]
#  [5.63]
#  [7.5 ]
#  [6.66]
#  [8.12]
#  [8.86]
#  [7.98]
#  [7.92]
#  [4.51]
#  [4.36]
#  [3.44]
#  [5.41]
#  [5.2 ]
#  [8.14]
#  [8.11]
#  [8.19]
#  [9.04]
#  [8.95]
#  [8.  ]
#  [8.73]
#  [6.35]
#  [3.76]
#  [4.52]
#  [5.77]
#  [4.87]
#  [6.09]
#  [8.59]
#  [8.25]
#  [8.6 ]
#  [9.4 ]
#  [9.27]
#  [9.47]
#  [8.88]
#  [6.62]
#  [5.04]
#  [4.72]
#  [5.54]
#  [6.28]
#  [7.04]
#  [7.42]
#  [8.25]
#  [8.65]
#  [9.01]
#  [7.03]
#  [6.29]
#  [3.27]
#  [2.51]
#  [4.28]
#  [5.39]
#  [6.92]
#  [7.56]]

# %%
# Normalisasi dataset
scaler = MinMaxScaler()
dataset = scaler.fit_transform(dataset)

# %%
# Fungsi membuat sequence
def buat_sequences(dataset, window_size):
    input = []
    output = []

    for i in range(len(dataset)-window_size+1):
        window = dataset[i:(i+window_size-4), 0]
        input.append(window)
        output.append(dataset[(i+window_size-4):i+window_size, 0])
    return np.array(input),np.array(output)

window_size = 16
dataInput, dataOutput = buat_sequences(dataset, window_size)

print(len(dataInput))
print(len(dataOutput))
# Out:
# 62
# 62

# %%
# Bagi data untuk training dan testing
input_train, input_test, output_train, output_test = train_test_split(dataInput, dataOutput, test_size=0.1, shuffle=False)

print(len(input_train))
print(len(input_test))
# Out:
# 55
# 7

# %%
# Ubah dimensinya untuk disesuaikan dengan model
input_train = input_train.reshape((input_train.shape[0], 1, 1, 1, window_size-4))
input_test = input_test.reshape((input_test.shape[0], 1, 1, 1, window_size-4))

print(input_test)
# Out:
# [[[[[0.98994253 0.97126437 1.         0.91522989 0.59051724 0.36350575
#      0.31752874 0.43534483 0.54166667 0.65086207 0.70545977 0.82471264]]]]
#
#
#
#  [[[[0.97126437 1.         0.91522989 0.59051724 0.36350575 0.31752874
#      0.43534483 0.54166667 0.65086207 0.70545977 0.82471264 0.88218391]]]]
#
#
#
#  [[[[1.         0.91522989 0.59051724 0.36350575 0.31752874 0.43534483
#      0.54166667 0.65086207 0.70545977 0.82471264 0.88218391 0.93390805]]]]
#
#
#
#  [[[[0.91522989 0.59051724 0.36350575 0.31752874 0.43534483 0.54166667
#      0.65086207 0.70545977 0.82471264 0.88218391 0.93390805 0.64942529]]]]
#
#
#
#  [[[[0.59051724 0.36350575 0.31752874 0.43534483 0.54166667 0.65086207
#      0.70545977 0.82471264 0.88218391 0.93390805 0.64942529 0.54310345]]]]
#
#
#
#  [[[[0.36350575 0.31752874 0.43534483 0.54166667 0.65086207 0.70545977
#      0.82471264 0.88218391 0.93390805 0.64942529 0.54310345 0.1091954 ]]]]
#
#
#
#  [[[[0.31752874 0.43534483 0.54166667 0.65086207 0.70545977 0.82471264
#      0.88218391 0.93390805 0.64942529 0.54310345 0.1091954  0.        ]]]]]

# %%
#model machine learning
model = tf.keras.models.Sequential([
  tf.keras.layers.ConvLSTM2D(filters=512, kernel_size=(1,1), activation='relu', input_shape=(1, 1, 1, window_size-4)),   
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(256, activation="relu"),
  tf.keras.layers.Dropout(0.1),
  tf.keras.layers.Dense(128, activation="relu"),
  tf.keras.layers.Dense(16, activation="relu"),
  tf.keras.layers.Dense(4, activation="relu"),
])

opt = keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=opt, loss='mean_squared_error',metrics=["mae"])

model.summary()

#fit the model
fitting_history = model.fit(input_train, output_train, validation_split=0.1, verbose=2, epochs=300)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d (ConvLSTM2D)    (None, 1, 1, 512)         1075200
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                2064
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 68
# =================================================================
# Total params: 1,241,556
# Trainable params: 1,241,556
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 2/2 - 3s - loss: 0.3508 - mae: 0.5289 - val_loss: 3.4103 - val_mae: 1.5927
# Epoch 2/300
# 2/2 - 0s - loss: 1.8030 - mae: 1.0573 - val_loss: 0.3520 - val_mae: 0.5717
# Epoch 3/300
# 2/2 - 0s - loss: 0.3218 - mae: 0.5028 - val_loss: 0.4203 - val_mae: 0.6260
# Epoch 4/300
# 2/2 - 0s - loss: 0.3421 - mae: 0.5259 - val_loss: 0.3605 - val_mae: 0.5725
# Epoch 5/300
# 2/2 - 0s - loss: 0.2860 - mae: 0.4639 - val_loss: 0.2373 - val_mae: 0.4439
# Epoch 6/300
# 2/2 - 0s - loss: 0.1803 - mae: 0.3559 - val_loss: 0.0781 - val_mae: 0.2219
# Epoch 7/300
# 2/2 - 0s - loss: 0.0957 - mae: 0.2575 - val_loss: 0.0899 - val_mae: 0.2396
# Epoch 8/300
# 2/2 - 0s - loss: 0.1207 - mae: 0.2832 - val_loss: 0.0423 - val_mae: 0.1620
# Epoch 9/300
# 2/2 - 0s - loss: 0.0792 - mae: 0.2440 - val_loss: 0.0512 - val_mae: 0.1921
# Epoch 10/300
# 2/2 - 0s - loss: 0.0746 - mae: 0.2335 - val_loss: 0.0739 - val_mae: 0.2336
# Epoch 11/300
# 2/2 - 0s - loss: 0.0850 - mae: 0.2445 - val_loss: 0.0701 - val_mae: 0.2283
# Epoch 12/300
# 2/2 - 0s - loss: 0.0792 - mae: 0.2392 - val_loss: 0.0485 - val_mae: 0.1887
# Epoch 13/300
# 2/2 - 0s - loss: 0.0667 - mae: 0.2242 - val_loss: 0.0277 - val_mae: 0.1386
# Epoch 14/300
# 2/2 - 0s - loss: 0.0615 - mae: 0.2187 - val_loss: 0.0201 - val_mae: 0.1201
# Epoch 15/300
# 2/2 - 0s - loss: 0.0681 - mae: 0.2257 - val_loss: 0.0203 - val_mae: 0.1193
# Epoch 16/300
# 2/2 - 0s - loss: 0.0662 - mae: 0.2209 - val_loss: 0.0210 - val_mae: 0.1178
# Epoch 17/300
# 2/2 - 0s - loss: 0.0626 - mae: 0.2215 - val_loss: 0.0266 - val_mae: 0.1348
# Epoch 18/300
# 2/2 - 0s - loss: 0.0583 - mae: 0.2136 - val_loss: 0.0371 - val_mae: 0.1629
# Epoch 19/300
# 2/2 - 0s - loss: 0.0607 - mae: 0.2155 - val_loss: 0.0409 - val_mae: 0.1727
# Epoch 20/300
# 2/2 - 0s - loss: 0.0604 - mae: 0.2152 - val_loss: 0.0378 - val_mae: 0.1651
# Epoch 21/300
# 2/2 - 0s - loss: 0.0565 - mae: 0.2073 - val_loss: 0.0290 - val_mae: 0.1428
# Epoch 22/300
# 2/2 - 0s - loss: 0.0548 - mae: 0.2066 - val_loss: 0.0213 - val_mae: 0.1213
# Epoch 23/300
# 2/2 - 0s - loss: 0.0540 - mae: 0.2057 - val_loss: 0.0178 - val_mae: 0.1101
# Epoch 24/300
# 2/2 - 0s - loss: 0.0522 - mae: 0.2006 - val_loss: 0.0156 - val_mae: 0.1039
# Epoch 25/300
# 2/2 - 0s - loss: 0.0518 - mae: 0.1984 - val_loss: 0.0151 - val_mae: 0.1027
# Epoch 26/300
# 2/2 - 0s - loss: 0.0512 - mae: 0.1968 - val_loss: 0.0159 - val_mae: 0.1049
# Epoch 27/300
# 2/2 - 0s - loss: 0.0502 - mae: 0.1944 - val_loss: 0.0176 - val_mae: 0.1126
# Epoch 28/300
# 2/2 - 0s - loss: 0.0455 - mae: 0.1836 - val_loss: 0.0157 - val_mae: 0.1046
# Epoch 29/300
# 2/2 - 0s - loss: 0.0460 - mae: 0.1837 - val_loss: 0.0123 - val_mae: 0.0894
# Epoch 30/300
# 2/2 - 0s - loss: 0.0440 - mae: 0.1780 - val_loss: 0.0116 - val_mae: 0.0826
# Epoch 31/300
# 2/2 - 0s - loss: 0.0426 - mae: 0.1729 - val_loss: 0.0113 - val_mae: 0.0849
# Epoch 32/300
# 2/2 - 0s - loss: 0.0411 - mae: 0.1674 - val_loss: 0.0121 - val_mae: 0.0902
# Epoch 33/300
# 2/2 - 0s - loss: 0.0397 - mae: 0.1640 - val_loss: 0.0140 - val_mae: 0.0977
# Epoch 34/300
# 2/2 - 0s - loss: 0.0386 - mae: 0.1613 - val_loss: 0.0137 - val_mae: 0.0968
# Epoch 35/300
# 2/2 - 0s - loss: 0.0365 - mae: 0.1554 - val_loss: 0.0143 - val_mae: 0.1044
# Epoch 36/300
# 2/2 - 0s - loss: 0.0389 - mae: 0.1581 - val_loss: 0.0158 - val_mae: 0.1103
# Epoch 37/300
# 2/2 - 0s - loss: 0.0382 - mae: 0.1551 - val_loss: 0.0158 - val_mae: 0.1045
# Epoch 38/300
# 2/2 - 0s - loss: 0.0392 - mae: 0.1581 - val_loss: 0.0207 - val_mae: 0.1129
# Epoch 39/300
# 2/2 - 0s - loss: 0.0409 - mae: 0.1631 - val_loss: 0.0183 - val_mae: 0.1047
# Epoch 40/300
# 2/2 - 0s - loss: 0.0373 - mae: 0.1553 - val_loss: 0.0164 - val_mae: 0.1131
# Epoch 41/300
# 2/2 - 0s - loss: 0.0400 - mae: 0.1591 - val_loss: 0.0191 - val_mae: 0.1234
# Epoch 42/300
# 2/2 - 0s - loss: 0.0398 - mae: 0.1576 - val_loss: 0.0156 - val_mae: 0.1105
# Epoch 43/300
# 2/2 - 0s - loss: 0.0396 - mae: 0.1605 - val_loss: 0.0160 - val_mae: 0.1034
# Epoch 44/300
# 2/2 - 0s - loss: 0.0370 - mae: 0.1558 - val_loss: 0.0161 - val_mae: 0.1027
# Epoch 45/300
# 2/2 - 0s - loss: 0.0402 - mae: 0.1607 - val_loss: 0.0153 - val_mae: 0.1000
# Epoch 46/300
# 2/2 - 0s - loss: 0.0377 - mae: 0.1553 - val_loss: 0.0138 - val_mae: 0.1019
# Epoch 47/300
# 2/2 - 0s - loss: 0.0383 - mae: 0.1563 - val_loss: 0.0140 - val_mae: 0.1035
# Epoch 48/300
# 2/2 - 0s - loss: 0.0388 - mae: 0.1566 - val_loss: 0.0134 - val_mae: 0.0993
# Epoch 49/300
# 2/2 - 0s - loss: 0.0376 - mae: 0.1570 - val_loss: 0.0142 - val_mae: 0.0967
# Epoch 50/300
# 2/2 - 0s - loss: 0.0378 - mae: 0.1571 - val_loss: 0.0164 - val_mae: 0.1049
# Epoch 51/300
# 2/2 - 0s - loss: 0.0409 - mae: 0.1657 - val_loss: 0.0155 - val_mae: 0.1013
# Epoch 52/300
# 2/2 - 0s - loss: 0.0376 - mae: 0.1557 - val_loss: 0.0131 - val_mae: 0.0983
# Epoch 53/300
# 2/2 - 0s - loss: 0.0387 - mae: 0.1588 - val_loss: 0.0148 - val_mae: 0.1069
# Epoch 54/300
# 2/2 - 0s - loss: 0.0423 - mae: 0.1648 - val_loss: 0.0133 - val_mae: 0.0960
# Epoch 55/300
# 2/2 - 0s - loss: 0.0390 - mae: 0.1611 - val_loss: 0.0183 - val_mae: 0.1127
# Epoch 56/300
# 2/2 - 0s - loss: 0.0387 - mae: 0.1593 - val_loss: 0.0166 - val_mae: 0.1057
# Epoch 57/300
# 2/2 - 0s - loss: 0.0375 - mae: 0.1557 - val_loss: 0.0133 - val_mae: 0.0964
# Epoch 58/300
# 2/2 - 0s - loss: 0.0373 - mae: 0.1526 - val_loss: 0.0131 - val_mae: 0.0992
# Epoch 59/300
# 2/2 - 0s - loss: 0.0379 - mae: 0.1549 - val_loss: 0.0129 - val_mae: 0.0961
# Epoch 60/300
# 2/2 - 0s - loss: 0.0363 - mae: 0.1524 - val_loss: 0.0129 - val_mae: 0.0969
# Epoch 61/300
# 2/2 - 0s - loss: 0.0374 - mae: 0.1539 - val_loss: 0.0134 - val_mae: 0.0979
# Epoch 62/300
# 2/2 - 0s - loss: 0.0369 - mae: 0.1537 - val_loss: 0.0156 - val_mae: 0.1022
# Epoch 63/300
# 2/2 - 0s - loss: 0.0367 - mae: 0.1543 - val_loss: 0.0147 - val_mae: 0.1006
# Epoch 64/300
# 2/2 - 0s - loss: 0.0355 - mae: 0.1492 - val_loss: 0.0139 - val_mae: 0.1007
# Epoch 65/300
# 2/2 - 0s - loss: 0.0363 - mae: 0.1526 - val_loss: 0.0135 - val_mae: 0.0993
# Epoch 66/300
# 2/2 - 0s - loss: 0.0371 - mae: 0.1560 - val_loss: 0.0137 - val_mae: 0.0970
# Epoch 67/300
# 2/2 - 0s - loss: 0.0365 - mae: 0.1543 - val_loss: 0.0135 - val_mae: 0.0974
# Epoch 68/300
# 2/2 - 0s - loss: 0.0357 - mae: 0.1525 - val_loss: 0.0131 - val_mae: 0.0968
# Epoch 69/300
# 2/2 - 0s - loss: 0.0364 - mae: 0.1525 - val_loss: 0.0138 - val_mae: 0.0980
# Epoch 70/300
# 2/2 - 0s - loss: 0.0366 - mae: 0.1532 - val_loss: 0.0146 - val_mae: 0.0993
# Epoch 71/300
# 2/2 - 0s - loss: 0.0340 - mae: 0.1482 - val_loss: 0.0169 - val_mae: 0.1061
# Epoch 72/300
# 2/2 - 0s - loss: 0.0352 - mae: 0.1532 - val_loss: 0.0149 - val_mae: 0.0997
# Epoch 73/300
# 2/2 - 0s - loss: 0.0350 - mae: 0.1498 - val_loss: 0.0137 - val_mae: 0.0982
# Epoch 74/300
# 2/2 - 0s - loss: 0.0335 - mae: 0.1465 - val_loss: 0.0155 - val_mae: 0.1030
# Epoch 75/300
# 2/2 - 0s - loss: 0.0350 - mae: 0.1520 - val_loss: 0.0156 - val_mae: 0.1040
# Epoch 76/300
# 2/2 - 0s - loss: 0.0334 - mae: 0.1484 - val_loss: 0.0138 - val_mae: 0.1020
# Epoch 77/300
# 2/2 - 0s - loss: 0.0315 - mae: 0.1410 - val_loss: 0.0136 - val_mae: 0.1022
# Epoch 78/300
# 2/2 - 0s - loss: 0.0344 - mae: 0.1478 - val_loss: 0.0149 - val_mae: 0.1043
# Epoch 79/300
# 2/2 - 0s - loss: 0.0313 - mae: 0.1410 - val_loss: 0.0183 - val_mae: 0.1130
# Epoch 80/300
# 2/2 - 0s - loss: 0.0327 - mae: 0.1468 - val_loss: 0.0135 - val_mae: 0.0984
# Epoch 81/300
# 2/2 - 0s - loss: 0.0322 - mae: 0.1439 - val_loss: 0.0122 - val_mae: 0.0966
# Epoch 82/300
# 2/2 - 0s - loss: 0.0347 - mae: 0.1456 - val_loss: 0.0121 - val_mae: 0.0925
# Epoch 83/300
# 2/2 - 0s - loss: 0.0320 - mae: 0.1426 - val_loss: 0.0147 - val_mae: 0.1008
# Epoch 84/300
# 2/2 - 0s - loss: 0.0308 - mae: 0.1419 - val_loss: 0.0113 - val_mae: 0.0899
# Epoch 85/300
# 2/2 - 0s - loss: 0.0297 - mae: 0.1377 - val_loss: 0.0111 - val_mae: 0.0896
# Epoch 86/300
# 2/2 - 0s - loss: 0.0310 - mae: 0.1409 - val_loss: 0.0136 - val_mae: 0.0994
# Epoch 87/300
# 2/2 - 0s - loss: 0.0271 - mae: 0.1321 - val_loss: 0.0123 - val_mae: 0.0951
# Epoch 88/300
# 2/2 - 0s - loss: 0.0256 - mae: 0.1281 - val_loss: 0.0106 - val_mae: 0.0886
# Epoch 89/300
# 2/2 - 0s - loss: 0.0292 - mae: 0.1373 - val_loss: 0.0105 - val_mae: 0.0876
# Epoch 90/300
# 2/2 - 0s - loss: 0.0254 - mae: 0.1274 - val_loss: 0.0109 - val_mae: 0.0881
# Epoch 91/300
# 2/2 - 0s - loss: 0.0260 - mae: 0.1299 - val_loss: 0.0094 - val_mae: 0.0829
# Epoch 92/300
# 2/2 - 0s - loss: 0.0263 - mae: 0.1295 - val_loss: 0.0087 - val_mae: 0.0770
# Epoch 93/300
# 2/2 - 0s - loss: 0.0230 - mae: 0.1234 - val_loss: 0.0091 - val_mae: 0.0746
# Epoch 94/300
# 2/2 - 0s - loss: 0.0264 - mae: 0.1323 - val_loss: 0.0083 - val_mae: 0.0680
# Epoch 95/300
# 2/2 - 0s - loss: 0.0233 - mae: 0.1224 - val_loss: 0.0076 - val_mae: 0.0663
# Epoch 96/300
# 2/2 - 0s - loss: 0.0227 - mae: 0.1216 - val_loss: 0.0084 - val_mae: 0.0732
# Epoch 97/300
# 2/2 - 0s - loss: 0.0251 - mae: 0.1246 - val_loss: 0.0072 - val_mae: 0.0655
# Epoch 98/300
# 2/2 - 0s - loss: 0.0209 - mae: 0.1153 - val_loss: 0.0073 - val_mae: 0.0645
# Epoch 99/300
# 2/2 - 0s - loss: 0.0228 - mae: 0.1199 - val_loss: 0.0064 - val_mae: 0.0582
# Epoch 100/300
# 2/2 - 0s - loss: 0.0206 - mae: 0.1158 - val_loss: 0.0056 - val_mae: 0.0536
# Epoch 101/300
# 2/2 - 0s - loss: 0.0209 - mae: 0.1175 - val_loss: 0.0064 - val_mae: 0.0577
# Epoch 102/300
# 2/2 - 0s - loss: 0.0219 - mae: 0.1189 - val_loss: 0.0063 - val_mae: 0.0552
# Epoch 103/300
# 2/2 - 0s - loss: 0.0213 - mae: 0.1168 - val_loss: 0.0070 - val_mae: 0.0569
# Epoch 104/300
# 2/2 - 0s - loss: 0.0191 - mae: 0.1099 - val_loss: 0.0084 - val_mae: 0.0667
# Epoch 105/300
# 2/2 - 0s - loss: 0.0202 - mae: 0.1112 - val_loss: 0.0071 - val_mae: 0.0606
# Epoch 106/300
# 2/2 - 0s - loss: 0.0190 - mae: 0.1104 - val_loss: 0.0062 - val_mae: 0.0552
# Epoch 107/300
# 2/2 - 0s - loss: 0.0195 - mae: 0.1130 - val_loss: 0.0062 - val_mae: 0.0534
# Epoch 108/300
# 2/2 - 0s - loss: 0.0212 - mae: 0.1153 - val_loss: 0.0058 - val_mae: 0.0528
# Epoch 109/300
# 2/2 - 0s - loss: 0.0193 - mae: 0.1104 - val_loss: 0.0052 - val_mae: 0.0536
# Epoch 110/300
# 2/2 - 0s - loss: 0.0185 - mae: 0.1117 - val_loss: 0.0058 - val_mae: 0.0603
# Epoch 111/300
# 2/2 - 0s - loss: 0.0202 - mae: 0.1142 - val_loss: 0.0055 - val_mae: 0.0538
# Epoch 112/300
# 2/2 - 0s - loss: 0.0206 - mae: 0.1131 - val_loss: 0.0069 - val_mae: 0.0678
# Epoch 113/300
# 2/2 - 0s - loss: 0.0200 - mae: 0.1154 - val_loss: 0.0120 - val_mae: 0.0988
# Epoch 114/300
# 2/2 - 0s - loss: 0.0199 - mae: 0.1151 - val_loss: 0.0052 - val_mae: 0.0455
# Epoch 115/300
# 2/2 - 0s - loss: 0.0222 - mae: 0.1206 - val_loss: 0.0053 - val_mae: 0.0520
# Epoch 116/300
# 2/2 - 0s - loss: 0.0180 - mae: 0.1072 - val_loss: 0.0091 - val_mae: 0.0774
# Epoch 117/300
# 2/2 - 0s - loss: 0.0207 - mae: 0.1147 - val_loss: 0.0086 - val_mae: 0.0642
# Epoch 118/300
# 2/2 - 0s - loss: 0.0205 - mae: 0.1146 - val_loss: 0.0048 - val_mae: 0.0462
# Epoch 119/300
# 2/2 - 0s - loss: 0.0188 - mae: 0.1107 - val_loss: 0.0150 - val_mae: 0.1118
# Epoch 120/300
# 2/2 - 0s - loss: 0.0245 - mae: 0.1239 - val_loss: 0.0084 - val_mae: 0.0794
# Epoch 121/300
# 2/2 - 0s - loss: 0.0201 - mae: 0.1132 - val_loss: 0.0072 - val_mae: 0.0556
# Epoch 122/300
# 2/2 - 0s - loss: 0.0208 - mae: 0.1174 - val_loss: 0.0071 - val_mae: 0.0673
# Epoch 123/300
# 2/2 - 0s - loss: 0.0203 - mae: 0.1148 - val_loss: 0.0157 - val_mae: 0.1156
# Epoch 124/300
# 2/2 - 0s - loss: 0.0210 - mae: 0.1172 - val_loss: 0.0049 - val_mae: 0.0549
# Epoch 125/300
# 2/2 - 0s - loss: 0.0202 - mae: 0.1133 - val_loss: 0.0040 - val_mae: 0.0430
# Epoch 126/300
# 2/2 - 0s - loss: 0.0176 - mae: 0.1053 - val_loss: 0.0115 - val_mae: 0.0975
# Epoch 127/300
# 2/2 - 0s - loss: 0.0197 - mae: 0.1150 - val_loss: 0.0067 - val_mae: 0.0656
# Epoch 128/300
# 2/2 - 0s - loss: 0.0173 - mae: 0.1079 - val_loss: 0.0043 - val_mae: 0.0373
# Epoch 129/300
# 2/2 - 0s - loss: 0.0197 - mae: 0.1106 - val_loss: 0.0034 - val_mae: 0.0411
# Epoch 130/300
# 2/2 - 0s - loss: 0.0152 - mae: 0.0988 - val_loss: 0.0085 - val_mae: 0.0838
# Epoch 131/300
# 2/2 - 0s - loss: 0.0179 - mae: 0.1103 - val_loss: 0.0060 - val_mae: 0.0675
# Epoch 132/300
# 2/2 - 0s - loss: 0.0147 - mae: 0.0981 - val_loss: 0.0034 - val_mae: 0.0381
# Epoch 133/300
# 2/2 - 0s - loss: 0.0176 - mae: 0.1060 - val_loss: 0.0045 - val_mae: 0.0528
# Epoch 134/300
# 2/2 - 0s - loss: 0.0181 - mae: 0.1071 - val_loss: 0.0072 - val_mae: 0.0756
# Epoch 135/300
# 2/2 - 0s - loss: 0.0152 - mae: 0.1005 - val_loss: 0.0039 - val_mae: 0.0450
# Epoch 136/300
# 2/2 - 0s - loss: 0.0151 - mae: 0.0970 - val_loss: 0.0041 - val_mae: 0.0468
# Epoch 137/300
# 2/2 - 0s - loss: 0.0195 - mae: 0.1076 - val_loss: 0.0076 - val_mae: 0.0815
# Epoch 138/300
# 2/2 - 0s - loss: 0.0160 - mae: 0.1018 - val_loss: 0.0043 - val_mae: 0.0509
# Epoch 139/300
# 2/2 - 0s - loss: 0.0138 - mae: 0.0935 - val_loss: 0.0043 - val_mae: 0.0406
# Epoch 140/300
# 2/2 - 0s - loss: 0.0156 - mae: 0.1007 - val_loss: 0.0053 - val_mae: 0.0587
# Epoch 141/300
# 2/2 - 0s - loss: 0.0163 - mae: 0.1031 - val_loss: 0.0061 - val_mae: 0.0684
# Epoch 142/300
# 2/2 - 0s - loss: 0.0167 - mae: 0.1024 - val_loss: 0.0035 - val_mae: 0.0434
# Epoch 143/300
# 2/2 - 0s - loss: 0.0174 - mae: 0.1056 - val_loss: 0.0056 - val_mae: 0.0605
# Epoch 144/300
# 2/2 - 0s - loss: 0.0155 - mae: 0.1015 - val_loss: 0.0039 - val_mae: 0.0451
# Epoch 145/300
# 2/2 - 0s - loss: 0.0137 - mae: 0.0958 - val_loss: 0.0031 - val_mae: 0.0396
# Epoch 146/300
# 2/2 - 0s - loss: 0.0148 - mae: 0.0962 - val_loss: 0.0050 - val_mae: 0.0558
# Epoch 147/300
# 2/2 - 0s - loss: 0.0148 - mae: 0.0979 - val_loss: 0.0045 - val_mae: 0.0518
# Epoch 148/300
# 2/2 - 0s - loss: 0.0151 - mae: 0.0963 - val_loss: 0.0039 - val_mae: 0.0491
# Epoch 149/300
# 2/2 - 0s - loss: 0.0139 - mae: 0.0938 - val_loss: 0.0044 - val_mae: 0.0551
# Epoch 150/300
# 2/2 - 0s - loss: 0.0138 - mae: 0.0974 - val_loss: 0.0049 - val_mae: 0.0571
# Epoch 151/300
# 2/2 - 0s - loss: 0.0153 - mae: 0.1011 - val_loss: 0.0034 - val_mae: 0.0452
# Epoch 152/300
# 2/2 - 0s - loss: 0.0147 - mae: 0.0957 - val_loss: 0.0045 - val_mae: 0.0531
# Epoch 153/300
# 2/2 - 0s - loss: 0.0136 - mae: 0.0922 - val_loss: 0.0051 - val_mae: 0.0560
# Epoch 154/300
# 2/2 - 0s - loss: 0.0147 - mae: 0.0948 - val_loss: 0.0050 - val_mae: 0.0593
# Epoch 155/300
# 2/2 - 0s - loss: 0.0135 - mae: 0.0929 - val_loss: 0.0037 - val_mae: 0.0519
# Epoch 156/300
# 2/2 - 0s - loss: 0.0148 - mae: 0.0972 - val_loss: 0.0024 - val_mae: 0.0368
# Epoch 157/300
# 2/2 - 0s - loss: 0.0128 - mae: 0.0905 - val_loss: 0.0039 - val_mae: 0.0497
# Epoch 158/300
# 2/2 - 0s - loss: 0.0128 - mae: 0.0908 - val_loss: 0.0036 - val_mae: 0.0457
# Epoch 159/300
# 2/2 - 0s - loss: 0.0135 - mae: 0.0938 - val_loss: 0.0039 - val_mae: 0.0425
# Epoch 160/300
# 2/2 - 0s - loss: 0.0139 - mae: 0.0937 - val_loss: 0.0044 - val_mae: 0.0570
# Epoch 161/300
# 2/2 - 0s - loss: 0.0127 - mae: 0.0930 - val_loss: 0.0046 - val_mae: 0.0589
# Epoch 162/300
# 2/2 - 0s - loss: 0.0135 - mae: 0.0951 - val_loss: 0.0043 - val_mae: 0.0564
# Epoch 163/300
# 2/2 - 0s - loss: 0.0128 - mae: 0.0913 - val_loss: 0.0048 - val_mae: 0.0597
# Epoch 164/300
# 2/2 - 0s - loss: 0.0121 - mae: 0.0874 - val_loss: 0.0042 - val_mae: 0.0532
# Epoch 165/300
# 2/2 - 0s - loss: 0.0128 - mae: 0.0920 - val_loss: 0.0033 - val_mae: 0.0459
# Epoch 166/300
# 2/2 - 0s - loss: 0.0129 - mae: 0.0910 - val_loss: 0.0041 - val_mae: 0.0562
# Epoch 167/300
# 2/2 - 0s - loss: 0.0115 - mae: 0.0843 - val_loss: 0.0062 - val_mae: 0.0715
# Epoch 168/300
# 2/2 - 0s - loss: 0.0125 - mae: 0.0908 - val_loss: 0.0038 - val_mae: 0.0480
# Epoch 169/300
# 2/2 - 0s - loss: 0.0145 - mae: 0.0964 - val_loss: 0.0042 - val_mae: 0.0477
# Epoch 170/300
# 2/2 - 0s - loss: 0.0135 - mae: 0.0898 - val_loss: 0.0076 - val_mae: 0.0781
# Epoch 171/300
# 2/2 - 0s - loss: 0.0130 - mae: 0.0925 - val_loss: 0.0041 - val_mae: 0.0486
# Epoch 172/300
# 2/2 - 0s - loss: 0.0135 - mae: 0.0916 - val_loss: 0.0043 - val_mae: 0.0543
# Epoch 173/300
# 2/2 - 0s - loss: 0.0133 - mae: 0.0889 - val_loss: 0.0054 - val_mae: 0.0647
# Epoch 174/300
# 2/2 - 0s - loss: 0.0134 - mae: 0.0938 - val_loss: 0.0038 - val_mae: 0.0517
# Epoch 175/300
# 2/2 - 0s - loss: 0.0127 - mae: 0.0921 - val_loss: 0.0039 - val_mae: 0.0518
# Epoch 176/300
# 2/2 - 0s - loss: 0.0120 - mae: 0.0875 - val_loss: 0.0042 - val_mae: 0.0552
# Epoch 177/300
# 2/2 - 0s - loss: 0.0115 - mae: 0.0847 - val_loss: 0.0057 - val_mae: 0.0662
# Epoch 178/300
# 2/2 - 0s - loss: 0.0124 - mae: 0.0896 - val_loss: 0.0045 - val_mae: 0.0547
# Epoch 179/300
# 2/2 - 0s - loss: 0.0112 - mae: 0.0846 - val_loss: 0.0032 - val_mae: 0.0431
# Epoch 180/300
# 2/2 - 0s - loss: 0.0135 - mae: 0.0921 - val_loss: 0.0030 - val_mae: 0.0413
# Epoch 181/300
# 2/2 - 0s - loss: 0.0111 - mae: 0.0833 - val_loss: 0.0040 - val_mae: 0.0537
# Epoch 182/300
# 2/2 - 0s - loss: 0.0131 - mae: 0.0923 - val_loss: 0.0045 - val_mae: 0.0587
# Epoch 183/300
# 2/2 - 0s - loss: 0.0131 - mae: 0.0945 - val_loss: 0.0059 - val_mae: 0.0608
# Epoch 184/300
# 2/2 - 0s - loss: 0.0133 - mae: 0.0919 - val_loss: 0.0074 - val_mae: 0.0778
# Epoch 185/300
# 2/2 - 0s - loss: 0.0123 - mae: 0.0906 - val_loss: 0.0045 - val_mae: 0.0582
# Epoch 186/300
# 2/2 - 0s - loss: 0.0112 - mae: 0.0846 - val_loss: 0.0034 - val_mae: 0.0426
# Epoch 187/300
# 2/2 - 0s - loss: 0.0116 - mae: 0.0839 - val_loss: 0.0077 - val_mae: 0.0779
# Epoch 188/300
# 2/2 - 0s - loss: 0.0145 - mae: 0.0958 - val_loss: 0.0039 - val_mae: 0.0512
# Epoch 189/300
# 2/2 - 0s - loss: 0.0111 - mae: 0.0847 - val_loss: 0.0042 - val_mae: 0.0482
# Epoch 190/300
# 2/2 - 0s - loss: 0.0126 - mae: 0.0899 - val_loss: 0.0061 - val_mae: 0.0697
# Epoch 191/300
# 2/2 - 0s - loss: 0.0136 - mae: 0.0951 - val_loss: 0.0046 - val_mae: 0.0541
# Epoch 192/300
# 2/2 - 0s - loss: 0.0122 - mae: 0.0890 - val_loss: 0.0048 - val_mae: 0.0495
# Epoch 193/300
# 2/2 - 0s - loss: 0.0116 - mae: 0.0855 - val_loss: 0.0095 - val_mae: 0.0910
# Epoch 194/300
# 2/2 - 0s - loss: 0.0135 - mae: 0.0938 - val_loss: 0.0032 - val_mae: 0.0452
# Epoch 195/300
# 2/2 - 0s - loss: 0.0132 - mae: 0.0906 - val_loss: 0.0032 - val_mae: 0.0399
# Epoch 196/300
# 2/2 - 0s - loss: 0.0119 - mae: 0.0869 - val_loss: 0.0092 - val_mae: 0.0864
# Epoch 197/300
# 2/2 - 0s - loss: 0.0136 - mae: 0.0958 - val_loss: 0.0043 - val_mae: 0.0554
# Epoch 198/300
# 2/2 - 0s - loss: 0.0119 - mae: 0.0849 - val_loss: 0.0042 - val_mae: 0.0507
# Epoch 199/300
# 2/2 - 0s - loss: 0.0136 - mae: 0.0924 - val_loss: 0.0128 - val_mae: 0.1049
# Epoch 200/300
# 2/2 - 0s - loss: 0.0160 - mae: 0.1061 - val_loss: 0.0034 - val_mae: 0.0429
# Epoch 201/300
# 2/2 - 0s - loss: 0.0129 - mae: 0.0878 - val_loss: 0.0042 - val_mae: 0.0391
# Epoch 202/300
# 2/2 - 0s - loss: 0.0129 - mae: 0.0879 - val_loss: 0.0088 - val_mae: 0.0864
# Epoch 203/300
# 2/2 - 0s - loss: 0.0133 - mae: 0.0966 - val_loss: 0.0078 - val_mae: 0.0778
# Epoch 204/300
# 2/2 - 0s - loss: 0.0106 - mae: 0.0836 - val_loss: 0.0041 - val_mae: 0.0545
# Epoch 205/300
# 2/2 - 0s - loss: 0.0127 - mae: 0.0888 - val_loss: 0.0051 - val_mae: 0.0615
# Epoch 206/300
# 2/2 - 0s - loss: 0.0136 - mae: 0.0934 - val_loss: 0.0051 - val_mae: 0.0606
# Epoch 207/300
# 2/2 - 0s - loss: 0.0124 - mae: 0.0909 - val_loss: 0.0036 - val_mae: 0.0469
# Epoch 208/300
# 2/2 - 0s - loss: 0.0117 - mae: 0.0868 - val_loss: 0.0058 - val_mae: 0.0675
# Epoch 209/300
# 2/2 - 0s - loss: 0.0105 - mae: 0.0837 - val_loss: 0.0050 - val_mae: 0.0620
# Epoch 210/300
# 2/2 - 0s - loss: 0.0109 - mae: 0.0855 - val_loss: 0.0047 - val_mae: 0.0585
# Epoch 211/300
# 2/2 - 0s - loss: 0.0105 - mae: 0.0836 - val_loss: 0.0057 - val_mae: 0.0649
# Epoch 212/300
# 2/2 - 0s - loss: 0.0103 - mae: 0.0836 - val_loss: 0.0055 - val_mae: 0.0586
# Epoch 213/300
# 2/2 - 0s - loss: 0.0102 - mae: 0.0798 - val_loss: 0.0078 - val_mae: 0.0823
# Epoch 214/300
# 2/2 - 0s - loss: 0.0115 - mae: 0.0888 - val_loss: 0.0050 - val_mae: 0.0627
# Epoch 215/300
# 2/2 - 0s - loss: 0.0099 - mae: 0.0806 - val_loss: 0.0040 - val_mae: 0.0521
# Epoch 216/300
# 2/2 - 0s - loss: 0.0118 - mae: 0.0878 - val_loss: 0.0045 - val_mae: 0.0594
# Epoch 217/300
# 2/2 - 0s - loss: 0.0115 - mae: 0.0870 - val_loss: 0.0047 - val_mae: 0.0610
# Epoch 218/300
# 2/2 - 0s - loss: 0.0101 - mae: 0.0803 - val_loss: 0.0034 - val_mae: 0.0481
# Epoch 219/300
# 2/2 - 0s - loss: 0.0102 - mae: 0.0823 - val_loss: 0.0038 - val_mae: 0.0502
# Epoch 220/300
# 2/2 - 0s - loss: 0.0120 - mae: 0.0868 - val_loss: 0.0041 - val_mae: 0.0532
# Epoch 221/300
# 2/2 - 0s - loss: 0.0106 - mae: 0.0832 - val_loss: 0.0065 - val_mae: 0.0726
# Epoch 222/300
# 2/2 - 0s - loss: 0.0114 - mae: 0.0855 - val_loss: 0.0055 - val_mae: 0.0671
# Epoch 223/300
# 2/2 - 0s - loss: 0.0099 - mae: 0.0794 - val_loss: 0.0034 - val_mae: 0.0494
# Epoch 224/300
# 2/2 - 0s - loss: 0.0098 - mae: 0.0803 - val_loss: 0.0029 - val_mae: 0.0441
# Epoch 225/300
# 2/2 - 0s - loss: 0.0109 - mae: 0.0833 - val_loss: 0.0059 - val_mae: 0.0696
# Epoch 226/300
# 2/2 - 0s - loss: 0.0114 - mae: 0.0856 - val_loss: 0.0061 - val_mae: 0.0704
# Epoch 227/300
# 2/2 - 0s - loss: 0.0099 - mae: 0.0781 - val_loss: 0.0050 - val_mae: 0.0612
# Epoch 228/300
# 2/2 - 0s - loss: 0.0115 - mae: 0.0855 - val_loss: 0.0058 - val_mae: 0.0666
# Epoch 229/300
# 2/2 - 0s - loss: 0.0098 - mae: 0.0799 - val_loss: 0.0049 - val_mae: 0.0534
# Epoch 230/300
# 2/2 - 0s - loss: 0.0096 - mae: 0.0779 - val_loss: 0.0058 - val_mae: 0.0651
# Epoch 231/300
# 2/2 - 0s - loss: 0.0099 - mae: 0.0792 - val_loss: 0.0074 - val_mae: 0.0790
# Epoch 232/300
# 2/2 - 0s - loss: 0.0112 - mae: 0.0864 - val_loss: 0.0037 - val_mae: 0.0508
# Epoch 233/300
# 2/2 - 0s - loss: 0.0104 - mae: 0.0811 - val_loss: 0.0034 - val_mae: 0.0496
# Epoch 234/300
# 2/2 - 0s - loss: 0.0105 - mae: 0.0836 - val_loss: 0.0039 - val_mae: 0.0531
# Epoch 235/300
# 2/2 - 0s - loss: 0.0101 - mae: 0.0819 - val_loss: 0.0048 - val_mae: 0.0603
# Epoch 236/300
# 2/2 - 0s - loss: 0.0098 - mae: 0.0809 - val_loss: 0.0067 - val_mae: 0.0750
# Epoch 237/300
# 2/2 - 0s - loss: 0.0092 - mae: 0.0790 - val_loss: 0.0037 - val_mae: 0.0479
# Epoch 238/300
# 2/2 - 0s - loss: 0.0105 - mae: 0.0812 - val_loss: 0.0041 - val_mae: 0.0535
# Epoch 239/300
# 2/2 - 0s - loss: 0.0092 - mae: 0.0773 - val_loss: 0.0054 - val_mae: 0.0646
# Epoch 240/300
# 2/2 - 0s - loss: 0.0094 - mae: 0.0799 - val_loss: 0.0047 - val_mae: 0.0584
# Epoch 241/300
# 2/2 - 0s - loss: 0.0111 - mae: 0.0820 - val_loss: 0.0056 - val_mae: 0.0680
# Epoch 242/300
# 2/2 - 0s - loss: 0.0100 - mae: 0.0808 - val_loss: 0.0040 - val_mae: 0.0542
# Epoch 243/300
# 2/2 - 0s - loss: 0.0104 - mae: 0.0819 - val_loss: 0.0037 - val_mae: 0.0521
# Epoch 244/300
# 2/2 - 0s - loss: 0.0099 - mae: 0.0815 - val_loss: 0.0051 - val_mae: 0.0634
# Epoch 245/300
# 2/2 - 0s - loss: 0.0094 - mae: 0.0793 - val_loss: 0.0041 - val_mae: 0.0523
# Epoch 246/300
# 2/2 - 0s - loss: 0.0090 - mae: 0.0750 - val_loss: 0.0057 - val_mae: 0.0667
# Epoch 247/300
# 2/2 - 0s - loss: 0.0095 - mae: 0.0797 - val_loss: 0.0052 - val_mae: 0.0638
# Epoch 248/300
# 2/2 - 0s - loss: 0.0097 - mae: 0.0799 - val_loss: 0.0033 - val_mae: 0.0428
# Epoch 249/300
# 2/2 - 0s - loss: 0.0112 - mae: 0.0838 - val_loss: 0.0061 - val_mae: 0.0695
# Epoch 250/300
# 2/2 - 0s - loss: 0.0102 - mae: 0.0835 - val_loss: 0.0060 - val_mae: 0.0696
# Epoch 251/300
# 2/2 - 0s - loss: 0.0097 - mae: 0.0818 - val_loss: 0.0044 - val_mae: 0.0521
# Epoch 252/300
# 2/2 - 0s - loss: 0.0113 - mae: 0.0830 - val_loss: 0.0047 - val_mae: 0.0602
# Epoch 253/300
# 2/2 - 0s - loss: 0.0103 - mae: 0.0830 - val_loss: 0.0040 - val_mae: 0.0531
# Epoch 254/300
# 2/2 - 0s - loss: 0.0100 - mae: 0.0787 - val_loss: 0.0051 - val_mae: 0.0603
# Epoch 255/300
# 2/2 - 0s - loss: 0.0093 - mae: 0.0787 - val_loss: 0.0075 - val_mae: 0.0783
# Epoch 256/300
# 2/2 - 0s - loss: 0.0103 - mae: 0.0813 - val_loss: 0.0054 - val_mae: 0.0610
# Epoch 257/300
# 2/2 - 0s - loss: 0.0094 - mae: 0.0790 - val_loss: 0.0046 - val_mae: 0.0545
# Epoch 258/300
# 2/2 - 0s - loss: 0.0096 - mae: 0.0797 - val_loss: 0.0064 - val_mae: 0.0730
# Epoch 259/300
# 2/2 - 0s - loss: 0.0091 - mae: 0.0791 - val_loss: 0.0041 - val_mae: 0.0547
# Epoch 260/300
# 2/2 - 0s - loss: 0.0106 - mae: 0.0809 - val_loss: 0.0052 - val_mae: 0.0645
# Epoch 261/300
# 2/2 - 0s - loss: 0.0096 - mae: 0.0797 - val_loss: 0.0058 - val_mae: 0.0666
# Epoch 262/300
# 2/2 - 0s - loss: 0.0106 - mae: 0.0849 - val_loss: 0.0040 - val_mae: 0.0424
# Epoch 263/300
# 2/2 - 0s - loss: 0.0114 - mae: 0.0840 - val_loss: 0.0063 - val_mae: 0.0710
# Epoch 264/300
# 2/2 - 0s - loss: 0.0095 - mae: 0.0805 - val_loss: 0.0077 - val_mae: 0.0798
# Epoch 265/300
# 2/2 - 0s - loss: 0.0098 - mae: 0.0818 - val_loss: 0.0040 - val_mae: 0.0429
# Epoch 266/300
# 2/2 - 0s - loss: 0.0098 - mae: 0.0782 - val_loss: 0.0050 - val_mae: 0.0618
# Epoch 267/300
# 2/2 - 0s - loss: 0.0103 - mae: 0.0846 - val_loss: 0.0045 - val_mae: 0.0568
# Epoch 268/300
# 2/2 - 0s - loss: 0.0088 - mae: 0.0761 - val_loss: 0.0048 - val_mae: 0.0557
# Epoch 269/300
# 2/2 - 0s - loss: 0.0109 - mae: 0.0841 - val_loss: 0.0111 - val_mae: 0.0961
# Epoch 270/300
# 2/2 - 0s - loss: 0.0118 - mae: 0.0884 - val_loss: 0.0047 - val_mae: 0.0581
# Epoch 271/300
# 2/2 - 0s - loss: 0.0105 - mae: 0.0796 - val_loss: 0.0035 - val_mae: 0.0483
# Epoch 272/300
# 2/2 - 0s - loss: 0.0083 - mae: 0.0739 - val_loss: 0.0051 - val_mae: 0.0635
# Epoch 273/300
# 2/2 - 0s - loss: 0.0098 - mae: 0.0808 - val_loss: 0.0062 - val_mae: 0.0699
# Epoch 274/300
# 2/2 - 0s - loss: 0.0091 - mae: 0.0779 - val_loss: 0.0059 - val_mae: 0.0665
# Epoch 275/300
# 2/2 - 0s - loss: 0.0093 - mae: 0.0785 - val_loss: 0.0070 - val_mae: 0.0746
# Epoch 276/300
# 2/2 - 0s - loss: 0.0090 - mae: 0.0780 - val_loss: 0.0040 - val_mae: 0.0496
# Epoch 277/300
# 2/2 - 0s - loss: 0.0102 - mae: 0.0792 - val_loss: 0.0056 - val_mae: 0.0664
# Epoch 278/300
# 2/2 - 0s - loss: 0.0096 - mae: 0.0805 - val_loss: 0.0081 - val_mae: 0.0817
# Epoch 279/300
# 2/2 - 0s - loss: 0.0093 - mae: 0.0779 - val_loss: 0.0049 - val_mae: 0.0532
# Epoch 280/300
# 2/2 - 0s - loss: 0.0098 - mae: 0.0768 - val_loss: 0.0063 - val_mae: 0.0702
# Epoch 281/300
# 2/2 - 0s - loss: 0.0125 - mae: 0.0889 - val_loss: 0.0042 - val_mae: 0.0555
# Epoch 282/300
# 2/2 - 0s - loss: 0.0090 - mae: 0.0750 - val_loss: 0.0034 - val_mae: 0.0437
# Epoch 283/300
# 2/2 - 0s - loss: 0.0131 - mae: 0.0911 - val_loss: 0.0075 - val_mae: 0.0788
# Epoch 284/300
# 2/2 - 0s - loss: 0.0108 - mae: 0.0865 - val_loss: 0.0058 - val_mae: 0.0564
# Epoch 285/300
# 2/2 - 0s - loss: 0.0108 - mae: 0.0826 - val_loss: 0.0052 - val_mae: 0.0564
# Epoch 286/300
# 2/2 - 0s - loss: 0.0091 - mae: 0.0774 - val_loss: 0.0072 - val_mae: 0.0757
# Epoch 287/300
# 2/2 - 0s - loss: 0.0116 - mae: 0.0868 - val_loss: 0.0032 - val_mae: 0.0442
# Epoch 288/300
# 2/2 - 0s - loss: 0.0109 - mae: 0.0828 - val_loss: 0.0050 - val_mae: 0.0614
# Epoch 289/300
# 2/2 - 0s - loss: 0.0110 - mae: 0.0852 - val_loss: 0.0061 - val_mae: 0.0677
# Epoch 290/300
# 2/2 - 0s - loss: 0.0097 - mae: 0.0794 - val_loss: 0.0051 - val_mae: 0.0561
# Epoch 291/300
# 2/2 - 0s - loss: 0.0105 - mae: 0.0819 - val_loss: 0.0093 - val_mae: 0.0894
# Epoch 292/300
# 2/2 - 0s - loss: 0.0106 - mae: 0.0859 - val_loss: 0.0061 - val_mae: 0.0701
# Epoch 293/300
# 2/2 - 0s - loss: 0.0101 - mae: 0.0800 - val_loss: 0.0041 - val_mae: 0.0438
# Epoch 294/300
# 2/2 - 0s - loss: 0.0115 - mae: 0.0819 - val_loss: 0.0052 - val_mae: 0.0635
# Epoch 295/300
# 2/2 - 0s - loss: 0.0103 - mae: 0.0823 - val_loss: 0.0064 - val_mae: 0.0695
# Epoch 296/300
# 2/2 - 0s - loss: 0.0088 - mae: 0.0775 - val_loss: 0.0057 - val_mae: 0.0587
# Epoch 297/300
# 2/2 - 0s - loss: 0.0102 - mae: 0.0830 - val_loss: 0.0092 - val_mae: 0.0892
# Epoch 298/300
# 2/2 - 0s - loss: 0.0113 - mae: 0.0870 - val_loss: 0.0035 - val_mae: 0.0499
# Epoch 299/300
# 2/2 - 0s - loss: 0.0093 - mae: 0.0764 - val_loss: 0.0033 - val_mae: 0.0416
# Epoch 300/300
# 2/2 - 0s - loss: 0.0105 - mae: 0.0829 - val_loss: 0.0083 - val_mae: 0.0825

# %%
# Grafik training dan validation loss
training_loss=fitting_history.history['loss']
validation_loss=fitting_history.history['val_loss']
epochs=range(len(training_loss))

plt.plot(epochs, training_loss, 'r', label="Training Loss")
plt.plot(epochs, validation_loss, 'b', label="Validation Loss")
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.figure()

# %%
# Grafik training and validation MAE
training_mae=fitting_history.history['mae']
validation_mae=fitting_history.history['val_mae']
epochs=range(len(training_mae))

plt.plot(epochs, training_mae, 'r', label="Training MAE")
plt.plot(epochs, validation_mae, 'b', label="Validation MAE")
plt.title('Training and validation MAE')
plt.legend(loc=0)
plt.figure()

# %%
# Menghitung nilai MSE dan MAE
mse_score, mae_score = model.evaluate(input_test, output_test)
print('Nilai Mean Squared Error (MSE) : ', mse_score)
print('Nilai Mean Absolute Error (MAE) : ', mae_score)
# Out:
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0363 - mae: 0.1467
# Nilai Mean Squared Error (MSE) :  0.03625916317105293
# Nilai Mean Absolute Error (MAE) :  0.14665625989437103

# %%
# Simpan model
model.save('model-lamapenyinaran.h5')

# %% [markdown]
# # **Testing Model**

# %%
# Load the model
model = tf.keras.models.load_model('model-lamapenyinaran.h5')

# %%
#Prediksi Data
data_prediksi = model.predict(input_test)

# %%
print(data_prediksi)
print("-------")
print(output_test)
# Out:
# [[0.8746855  0.884207   0.78415155 0.68912816]
#  [0.90488994 0.73905444 0.75189155 0.37936348]
#  [0.88711    0.8553655  0.6071869  0.3141486 ]
#  [0.5956875  0.38523027 0.18652755 0.25726408]
#  [0.3844351  0.19974066 0.28564587 0.34043705]
#  [0.26966235 0.28288564 0.3893372  0.50810564]
#  [0.37124646 0.4427051  0.567999   0.67429066]]
# -------
# [[0.88218391 0.93390805 0.64942529 0.54310345]
#  [0.93390805 0.64942529 0.54310345 0.1091954 ]
#  [0.64942529 0.54310345 0.1091954  0.        ]
#  [0.54310345 0.1091954  0.         0.25431034]
#  [0.1091954  0.         0.25431034 0.4137931 ]
#  [0.         0.25431034 0.4137931  0.63362069]
#  [0.25431034 0.4137931  0.63362069 0.72557471]]

# %%
# Inverse transform data min max
data_prediksi = scaler.inverse_transform(data_prediksi)
output_test = scaler.inverse_transform(output_test)

# %%
print(data_prediksi)
print("-------")
print(output_test)
# Out:
# [[8.597812  8.664081  7.9676948 7.306332 ]
#  [8.808034  7.653819  7.7431655 5.1503696]
#  [8.684285  8.463344  6.736021  4.696474 ]
#  [6.655985  5.191203  3.8082318 4.300558 ]
#  [5.1856685 3.900195  4.4980955 4.8794417]
#  [4.3868504 4.478884  5.219787  6.0464153]
#  [5.0938754 5.5912275 6.463273  7.203063 ]]
# -------
# [[8.65 9.01 7.03 6.29]
#  [9.01 7.03 6.29 3.27]
#  [7.03 6.29 3.27 2.51]
#  [6.29 3.27 2.51 4.28]
#  [3.27 2.51 4.28 5.39]
#  [2.51 4.28 5.39 6.92]
#  [4.28 5.39 6.92 7.56]]

# %%
temp_test=[]
number=[]
count=1

for j in output_test[0]:
  temp_test.append(j)
  number.append(count)
  count+=1
  
print(temp_test)
print(number)

temp_predict=[]
number=[]
count=1

for j in data_prediksi[0]:
  temp_predict.append(j)
  number.append(count)
  count+=1
  
print(temp_predict)
print(number)

# Grafik garis dari Suhu
plt.plot(number,temp_predict,marker='o',color="yellow")
plt.plot(number,temp_test,marker='o',color="black")
plt.title('Lama Penyinaran')
plt.ylabel('Jam')
plt.xlabel('Bulan')
plt.show()
# Out:
# [8.65, 9.01, 7.03, 6.290000000000001]
# [1, 2, 3, 4]
# [8.597812, 8.664081, 7.9676948, 7.306332]
# [1, 2, 3, 4]

# %%
temp_test=[]
number=[]
count=1

for j in output_test[1]:
  temp_test.append(j)
  number.append(count)
  count+=1
  
print(temp_test)
print(number)

temp_predict=[]
number=[]
count=1

for j in data_prediksi[1]:
  temp_predict.append(j)
  number.append(count)
  count+=1
  
print(temp_predict)
print(number)

# Grafik garis dari Suhu
plt.plot(number,temp_predict,marker='o',color="yellow")
plt.plot(number,temp_test,marker='o',color="black")
plt.title('Lama Penyinaran')
plt.ylabel('Jam')
plt.xlabel('Bulan')
plt.show()
# Out:
# [9.01, 7.03, 6.290000000000001, 3.27]
# [1, 2, 3, 4]
# [8.808034, 7.653819, 7.7431655, 5.1503696]
# [1, 2, 3, 4]

# %%
temp_test=[]
number=[]
count=1

for j in output_test[2]:
  temp_test.append(j)
  number.append(count)
  count+=1
  
print(temp_test)
print(number)

temp_predict=[]
number=[]
count=1

for j in data_prediksi[2]:
  temp_predict.append(j)
  number.append(count)
  count+=1
  
print(temp_predict)
print(number)

# Grafik garis dari Suhu
plt.plot(number,temp_predict,marker='o',color="yellow")
plt.plot(number,temp_test,marker='o',color="black")
plt.title('Lama Penyinaran')
plt.ylabel('Jam')
plt.xlabel('Bulan')
plt.show()
# Out:
# [7.03, 6.290000000000001, 3.27, 2.51]
# [1, 2, 3, 4]
# [8.684285, 8.463344, 6.736021, 4.696474]
# [1, 2, 3, 4]

# %%
temp_test=[]
number=[]
count=1

for j in output_test[3]:
  temp_test.append(j)
  number.append(count)
  count+=1
  
print(temp_test)
print(number)

temp_predict=[]
number=[]
count=1

for j in data_prediksi[3]:
  temp_predict.append(j)
  number.append(count)
  count+=1
  
print(temp_predict)
print(number)

# Grafik garis dari Suhu
plt.plot(number,temp_predict,marker='o',color="yellow")
plt.plot(number,temp_test,marker='o',color="black")
plt.title('Lama Penyinaran')
plt.ylabel('Jam')
plt.xlabel('Bulan')
plt.show()
# Out:
# [6.290000000000001, 3.27, 2.51, 4.28]
# [1, 2, 3, 4]
# [6.655985, 5.191203, 3.8082318, 4.300558]
# [1, 2, 3, 4]

# %%
temp_test=[]
number=[]
count=1

for j in output_test[4]:
  temp_test.append(j)
  number.append(count)
  count+=1
  
print(temp_test)
print(number)

temp_predict=[]
number=[]
count=1

for j in data_prediksi[4]:
  temp_predict.append(j)
  number.append(count)
  count+=1
  
print(temp_predict)
print(number)

# Grafik garis dari Suhu
plt.plot(number,temp_predict,marker='o',color="yellow")
plt.plot(number,temp_test,marker='o',color="black")
plt.title('Lama Penyinaran')
plt.ylabel('Jam')
plt.xlabel('Bulan')
plt.show()
# Out:
# [3.27, 2.51, 4.28, 5.39]
# [1, 2, 3, 4]
# [5.1856685, 3.900195, 4.4980955, 4.8794417]
# [1, 2, 3, 4]

# %%
temp_test=[]
number=[]
count=1

for j in output_test[5]:
  temp_test.append(j)
  number.append(count)
  count+=1
  
print(temp_test)
print(number)

temp_predict=[]
number=[]
count=1

for j in data_prediksi[5]:
  temp_predict.append(j)
  number.append(count)
  count+=1
  
print(temp_predict)
print(number)

# Grafik garis dari Suhu
plt.plot(number,temp_predict,marker='o',color="yellow")
plt.plot(number,temp_test,marker='o',color="black")
plt.title('Lama Penyinaran')
plt.ylabel('Jam')
plt.xlabel('Bulan')
plt.show()
# Out:
# [2.51, 4.28, 5.39, 6.92]
# [1, 2, 3, 4]
# [4.3868504, 4.478884, 5.219787, 6.0464153]
# [1, 2, 3, 4]

# %%
temp_test=[]
number=[]
count=1

for j in output_test[6]:
  temp_test.append(j)
  number.append(count)
  count+=1
  
print(temp_test)
print(number)

temp_predict=[]
number=[]
count=1

for j in data_prediksi[6]:
  temp_predict.append(j)
  number.append(count)
  count+=1
  
print(temp_predict)
print(number)

# Grafik garis dari Suhu
plt.plot(number,temp_predict,marker='o',color="yellow")
plt.plot(number,temp_test,marker='o',color="black")
plt.title('Lama Penyinaran')
plt.ylabel('Jam')
plt.xlabel('Bulan')
plt.show()
# Out:
# [4.28, 5.39, 6.92, 7.56]
# [1, 2, 3, 4]
# [5.0938754, 5.5912275, 6.463273, 7.203063]
# [1, 2, 3, 4]
