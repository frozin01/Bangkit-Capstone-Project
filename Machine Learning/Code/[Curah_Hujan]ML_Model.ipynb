# %% [markdown]
# <a href="https://colab.research.google.com/github/u1-byte/SmartCropYieldsPrediction/blob/main/Machine%20Learning/Code/%5BCurah_Hujan%5DML_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import library
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from google.colab import files
import csv
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
# Upload file dataset dari lokal
uploaded = files.upload()
# Out:
#      <input type="file" id="files-19a6c375-03b7-4a26-8211-1235d1e70756" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-19a6c375-03b7-4a26-8211-1235d1e70756">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Cuaca - Copy.csv to Cuaca - Copy.csv

# %% [markdown]
# # **Provinsi Jatim**

# %%
# Input data Jatim
input_curah_hujan_ratarata = []
number_of_input = []
number=1

# Baca file.csv
with open('/content/Cuaca.csv') as csv_file:
  csv_reader = csv.reader(csv_file, delimiter=',')
  next(csv_reader)
  for row in csv_reader:
    number_of_input.append(number)
    input_curah_hujan_ratarata.append(float(row[3]))
    number+=1

# %%
# Grafik garis dari Suhu
plt.plot(number_of_input,input_curah_hujan_ratarata,marker='o')
plt.title('Curah Hujan (2015 - 2020)')
plt.ylabel('mm')
plt.xlabel('Bulan')
plt.show()

# %%
# Input dari data pada database
dataset = []
counter=0

# Baca file.csv
with open('/content/Cuaca.csv') as csv_file:
  csv_reader = csv.reader(csv_file, delimiter=',')
  next(csv_reader)
  for row in csv_reader:
    dataset.append([])
    dataset[counter].append(float(row[3]))
    counter+=1

dataset = np.array(dataset)

print(dataset)
# Out:
# [[1.660e+01]
#  [1.760e+01]
#  [1.601e+01]
#  [8.820e+00]
#  [6.260e+00]
#  [0.000e+00]
#  [6.000e-02]
#  [6.900e-01]
#  [0.000e+00]
#  [0.000e+00]
#  [1.880e+00]
#  [4.410e+00]
#  [6.450e+00]
#  [2.457e+01]
#  [1.094e+01]
#  [9.040e+00]
#  [1.445e+01]
#  [6.950e+00]
#  [7.220e+00]
#  [3.600e+00]
#  [5.270e+00]
#  [1.663e+01]
#  [4.170e+00]
#  [9.850e+00]
#  [1.269e+01]
#  [1.124e+01]
#  [9.350e+00]
#  [1.045e+01]
#  [2.570e+00]
#  [2.210e+00]
#  [1.330e+00]
#  [0.000e+00]
#  [1.000e-02]
#  [2.860e+00]
#  [1.103e+01]
#  [1.469e+01]
#  [1.088e+01]
#  [1.745e+01]
#  [1.603e+01]
#  [1.037e+01]
#  [0.000e+00]
#  [4.610e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [7.200e-01]
#  [0.000e+00]
#  [6.970e+00]
#  [1.610e+01]
#  [1.626e+01]
#  [1.735e+01]
#  [1.145e+01]
#  [1.279e+01]
#  [1.800e+00]
#  [0.000e+00]
#  [3.000e-02]
#  [0.000e+00]
#  [0.000e+00]
#  [0.000e+00]
#  [8.800e-01]
#  [7.080e+00]
#  [1.145e+01]
#  [1.884e+01]
#  [1.053e+01]
#  [1.342e+01]
#  [1.813e+01]
#  [1.810e+00]
#  [1.000e-01]
#  [8.800e-01]
#  [0.000e+00]
#  [1.990e+00]
#  [6.700e+00]
#  [2.184e+01]
#  [1.971e+01]
#  [1.666e+01]
#  [9.350e+00]
#  [4.430e+00]
#  [3.900e-01]]

# %%
# Normalisasi dataset
scaler = MinMaxScaler()
dataset = scaler.fit_transform(dataset)

# %%
# Fungsi membuat sequence
def buat_sequences(dataset, window_size):
    input = []
    output = []

    for i in range(len(dataset)-window_size+1):
        window = dataset[i:(i+window_size-4), 0]
        input.append(window)
        output.append(dataset[(i+window_size-4):i+window_size, 0])
    return np.array(input),np.array(output)

window_size = 16
dataInput, dataOutput = buat_sequences(dataset, window_size)

print(len(dataInput))
print(len(dataOutput))
# Out:
# 62
# 62

# %%
# Bagi data untuk training dan testing
input_train, input_test, output_train, output_test = train_test_split(dataInput, dataOutput, test_size=0.1, shuffle=False)

print(len(input_train))
print(len(input_test))
# Out:
# 55
# 7

# %%
# Ubah dimensinya untuk disesuaikan dengan model
input_train = input_train.reshape((input_train.shape[0], 1, 1, 1, window_size-4))
input_test = input_test.reshape((input_test.shape[0], 1, 1, 1, window_size-4))

print(input_test)
# Out:
# [[[[[0.         0.         0.         0.03581604 0.28815629 0.46601547
#      0.76678877 0.42857143 0.54619455 0.73789174 0.07366707 0.00407   ]]]]
#
#
#
#  [[[[0.         0.         0.03581604 0.28815629 0.46601547 0.76678877
#      0.42857143 0.54619455 0.73789174 0.07366707 0.00407    0.03581604]]]]
#
#
#
#  [[[[0.         0.03581604 0.28815629 0.46601547 0.76678877 0.42857143
#      0.54619455 0.73789174 0.07366707 0.00407    0.03581604 0.        ]]]]
#
#
#
#  [[[[0.03581604 0.28815629 0.46601547 0.76678877 0.42857143 0.54619455
#      0.73789174 0.07366707 0.00407    0.03581604 0.         0.08099308]]]]
#
#
#
#  [[[[0.28815629 0.46601547 0.76678877 0.42857143 0.54619455 0.73789174
#      0.07366707 0.00407    0.03581604 0.         0.08099308 0.27269027]]]]
#
#
#
#  [[[[0.46601547 0.76678877 0.42857143 0.54619455 0.73789174 0.07366707
#      0.00407    0.03581604 0.         0.08099308 0.27269027 0.88888889]]]]
#
#
#
#  [[[[0.76678877 0.42857143 0.54619455 0.73789174 0.07366707 0.00407
#      0.03581604 0.         0.08099308 0.27269027 0.88888889 0.8021978 ]]]]]

# %%
#model machine learning
model = tf.keras.models.Sequential([
  tf.keras.layers.ConvLSTM2D(filters=512, kernel_size=(1,1), activation='relu', input_shape=(1, 1, 1, window_size-4)),   
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(256, activation="relu"),
  tf.keras.layers.Dropout(0.1),
  tf.keras.layers.Dense(128, activation="relu"),
  tf.keras.layers.Dense(16, activation="relu"),
  tf.keras.layers.Dense(4, activation="relu"),
])

opt = keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=opt, loss='mean_squared_error',metrics=["mae"])

model.summary()

#fit the model
fitting_history = model.fit(input_train, output_train, validation_split=0.1, verbose=2, epochs=300)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d_11 (ConvLSTM2D) (None, 1, 1, 512)         1075200
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 512)               0
# _________________________________________________________________
# dense_44 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_45 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_46 (Dense)             (None, 16)                2064
# _________________________________________________________________
# dense_47 (Dense)             (None, 4)                 68
# =================================================================
# Total params: 1,241,556
# Trainable params: 1,241,556
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 2/2 - 3s - loss: 0.1535 - mae: 0.3050 - val_loss: 0.0843 - val_mae: 0.2508
# Epoch 2/300
# 2/2 - 0s - loss: 0.0821 - mae: 0.2385 - val_loss: 0.0693 - val_mae: 0.2296
# Epoch 3/300
# 2/2 - 0s - loss: 0.0558 - mae: 0.1969 - val_loss: 0.0877 - val_mae: 0.2253
# Epoch 4/300
# 2/2 - 0s - loss: 0.0633 - mae: 0.2024 - val_loss: 0.0628 - val_mae: 0.2123
# Epoch 5/300
# 2/2 - 0s - loss: 0.0423 - mae: 0.1732 - val_loss: 0.0617 - val_mae: 0.2226
# Epoch 6/300
# 2/2 - 0s - loss: 0.0525 - mae: 0.1892 - val_loss: 0.0560 - val_mae: 0.2009
# Epoch 7/300
# 2/2 - 0s - loss: 0.0408 - mae: 0.1677 - val_loss: 0.0647 - val_mae: 0.2044
# Epoch 8/300
# 2/2 - 0s - loss: 0.0455 - mae: 0.1758 - val_loss: 0.0606 - val_mae: 0.2015
# Epoch 9/300
# 2/2 - 0s - loss: 0.0406 - mae: 0.1656 - val_loss: 0.0532 - val_mae: 0.1944
# Epoch 10/300
# 2/2 - 0s - loss: 0.0388 - mae: 0.1632 - val_loss: 0.0529 - val_mae: 0.1987
# Epoch 11/300
# 2/2 - 0s - loss: 0.0409 - mae: 0.1668 - val_loss: 0.0529 - val_mae: 0.1954
# Epoch 12/300
# 2/2 - 0s - loss: 0.0386 - mae: 0.1639 - val_loss: 0.0548 - val_mae: 0.1967
# Epoch 13/300
# 2/2 - 0s - loss: 0.0371 - mae: 0.1617 - val_loss: 0.0550 - val_mae: 0.1950
# Epoch 14/300
# 2/2 - 0s - loss: 0.0372 - mae: 0.1604 - val_loss: 0.0518 - val_mae: 0.1880
# Epoch 15/300
# 2/2 - 0s - loss: 0.0351 - mae: 0.1542 - val_loss: 0.0487 - val_mae: 0.1826
# Epoch 16/300
# 2/2 - 0s - loss: 0.0357 - mae: 0.1540 - val_loss: 0.0464 - val_mae: 0.1795
# Epoch 17/300
# 2/2 - 0s - loss: 0.0342 - mae: 0.1512 - val_loss: 0.0467 - val_mae: 0.1760
# Epoch 18/300
# 2/2 - 0s - loss: 0.0326 - mae: 0.1464 - val_loss: 0.0463 - val_mae: 0.1759
# Epoch 19/300
# 2/2 - 0s - loss: 0.0322 - mae: 0.1455 - val_loss: 0.0445 - val_mae: 0.1747
# Epoch 20/300
# 2/2 - 0s - loss: 0.0308 - mae: 0.1425 - val_loss: 0.0426 - val_mae: 0.1748
# Epoch 21/300
# 2/2 - 0s - loss: 0.0299 - mae: 0.1380 - val_loss: 0.0418 - val_mae: 0.1703
# Epoch 22/300
# 2/2 - 0s - loss: 0.0267 - mae: 0.1285 - val_loss: 0.0426 - val_mae: 0.1634
# Epoch 23/300
# 2/2 - 0s - loss: 0.0273 - mae: 0.1290 - val_loss: 0.0420 - val_mae: 0.1668
# Epoch 24/300
# 2/2 - 0s - loss: 0.0259 - mae: 0.1257 - val_loss: 0.0417 - val_mae: 0.1756
# Epoch 25/300
# 2/2 - 0s - loss: 0.0244 - mae: 0.1234 - val_loss: 0.0417 - val_mae: 0.1727
# Epoch 26/300
# 2/2 - 0s - loss: 0.0233 - mae: 0.1176 - val_loss: 0.0414 - val_mae: 0.1685
# Epoch 27/300
# 2/2 - 0s - loss: 0.0224 - mae: 0.1167 - val_loss: 0.0416 - val_mae: 0.1707
# Epoch 28/300
# 2/2 - 0s - loss: 0.0219 - mae: 0.1150 - val_loss: 0.0421 - val_mae: 0.1705
# Epoch 29/300
# 2/2 - 0s - loss: 0.0203 - mae: 0.1111 - val_loss: 0.0406 - val_mae: 0.1700
# Epoch 30/300
# 2/2 - 0s - loss: 0.0208 - mae: 0.1107 - val_loss: 0.0395 - val_mae: 0.1668
# Epoch 31/300
# 2/2 - 0s - loss: 0.0194 - mae: 0.1081 - val_loss: 0.0400 - val_mae: 0.1629
# Epoch 32/300
# 2/2 - 0s - loss: 0.0185 - mae: 0.1011 - val_loss: 0.0362 - val_mae: 0.1566
# Epoch 33/300
# 2/2 - 0s - loss: 0.0185 - mae: 0.1047 - val_loss: 0.0425 - val_mae: 0.1691
# Epoch 34/300
# 2/2 - 0s - loss: 0.0189 - mae: 0.1046 - val_loss: 0.0370 - val_mae: 0.1594
# Epoch 35/300
# 2/2 - 0s - loss: 0.0176 - mae: 0.0994 - val_loss: 0.0339 - val_mae: 0.1496
# Epoch 36/300
# 2/2 - 0s - loss: 0.0168 - mae: 0.0955 - val_loss: 0.0383 - val_mae: 0.1526
# Epoch 37/300
# 2/2 - 0s - loss: 0.0165 - mae: 0.0956 - val_loss: 0.0380 - val_mae: 0.1638
# Epoch 38/300
# 2/2 - 0s - loss: 0.0170 - mae: 0.1012 - val_loss: 0.0379 - val_mae: 0.1617
# Epoch 39/300
# 2/2 - 0s - loss: 0.0164 - mae: 0.0977 - val_loss: 0.0372 - val_mae: 0.1564
# Epoch 40/300
# 2/2 - 0s - loss: 0.0165 - mae: 0.0947 - val_loss: 0.0393 - val_mae: 0.1640
# Epoch 41/300
# 2/2 - 0s - loss: 0.0154 - mae: 0.0943 - val_loss: 0.0387 - val_mae: 0.1647
# Epoch 42/300
# 2/2 - 0s - loss: 0.0154 - mae: 0.0956 - val_loss: 0.0391 - val_mae: 0.1524
# Epoch 43/300
# 2/2 - 0s - loss: 0.0176 - mae: 0.0992 - val_loss: 0.0408 - val_mae: 0.1642
# Epoch 44/300
# 2/2 - 0s - loss: 0.0157 - mae: 0.0943 - val_loss: 0.0393 - val_mae: 0.1648
# Epoch 45/300
# 2/2 - 0s - loss: 0.0157 - mae: 0.0939 - val_loss: 0.0395 - val_mae: 0.1611
# Epoch 46/300
# 2/2 - 0s - loss: 0.0154 - mae: 0.0916 - val_loss: 0.0393 - val_mae: 0.1580
# Epoch 47/300
# 2/2 - 0s - loss: 0.0167 - mae: 0.0955 - val_loss: 0.0327 - val_mae: 0.1475
# Epoch 48/300
# 2/2 - 0s - loss: 0.0156 - mae: 0.0925 - val_loss: 0.0389 - val_mae: 0.1641
# Epoch 49/300
# 2/2 - 0s - loss: 0.0145 - mae: 0.0897 - val_loss: 0.0477 - val_mae: 0.1790
# Epoch 50/300
# 2/2 - 0s - loss: 0.0150 - mae: 0.0932 - val_loss: 0.0433 - val_mae: 0.1716
# Epoch 51/300
# 2/2 - 0s - loss: 0.0141 - mae: 0.0886 - val_loss: 0.0356 - val_mae: 0.1583
# Epoch 52/300
# 2/2 - 0s - loss: 0.0150 - mae: 0.0917 - val_loss: 0.0424 - val_mae: 0.1741
# Epoch 53/300
# 2/2 - 0s - loss: 0.0135 - mae: 0.0870 - val_loss: 0.0502 - val_mae: 0.1854
# Epoch 54/300
# 2/2 - 0s - loss: 0.0144 - mae: 0.0920 - val_loss: 0.0406 - val_mae: 0.1695
# Epoch 55/300
# 2/2 - 0s - loss: 0.0127 - mae: 0.0846 - val_loss: 0.0343 - val_mae: 0.1524
# Epoch 56/300
# 2/2 - 0s - loss: 0.0136 - mae: 0.0839 - val_loss: 0.0393 - val_mae: 0.1641
# Epoch 57/300
# 2/2 - 0s - loss: 0.0130 - mae: 0.0846 - val_loss: 0.0446 - val_mae: 0.1757
# Epoch 58/300
# 2/2 - 0s - loss: 0.0125 - mae: 0.0850 - val_loss: 0.0434 - val_mae: 0.1720
# Epoch 59/300
# 2/2 - 0s - loss: 0.0128 - mae: 0.0841 - val_loss: 0.0399 - val_mae: 0.1687
# Epoch 60/300
# 2/2 - 0s - loss: 0.0127 - mae: 0.0825 - val_loss: 0.0390 - val_mae: 0.1645
# Epoch 61/300
# 2/2 - 0s - loss: 0.0130 - mae: 0.0808 - val_loss: 0.0413 - val_mae: 0.1697
# Epoch 62/300
# 2/2 - 0s - loss: 0.0125 - mae: 0.0811 - val_loss: 0.0449 - val_mae: 0.1792
# Epoch 63/300
# 2/2 - 0s - loss: 0.0124 - mae: 0.0815 - val_loss: 0.0362 - val_mae: 0.1523
# Epoch 64/300
# 2/2 - 0s - loss: 0.0115 - mae: 0.0772 - val_loss: 0.0326 - val_mae: 0.1426
# Epoch 65/300
# 2/2 - 0s - loss: 0.0115 - mae: 0.0784 - val_loss: 0.0357 - val_mae: 0.1522
# Epoch 66/300
# 2/2 - 0s - loss: 0.0119 - mae: 0.0789 - val_loss: 0.0395 - val_mae: 0.1631
# Epoch 67/300
# 2/2 - 0s - loss: 0.0106 - mae: 0.0747 - val_loss: 0.0447 - val_mae: 0.1746
# Epoch 68/300
# 2/2 - 0s - loss: 0.0109 - mae: 0.0792 - val_loss: 0.0390 - val_mae: 0.1643
# Epoch 69/300
# 2/2 - 0s - loss: 0.0112 - mae: 0.0754 - val_loss: 0.0365 - val_mae: 0.1521
# Epoch 70/300
# 2/2 - 0s - loss: 0.0103 - mae: 0.0746 - val_loss: 0.0354 - val_mae: 0.1555
# Epoch 71/300
# 2/2 - 0s - loss: 0.0106 - mae: 0.0769 - val_loss: 0.0354 - val_mae: 0.1573
# Epoch 72/300
# 2/2 - 0s - loss: 0.0092 - mae: 0.0711 - val_loss: 0.0353 - val_mae: 0.1551
# Epoch 73/300
# 2/2 - 0s - loss: 0.0092 - mae: 0.0694 - val_loss: 0.0367 - val_mae: 0.1584
# Epoch 74/300
# 2/2 - 0s - loss: 0.0088 - mae: 0.0701 - val_loss: 0.0381 - val_mae: 0.1655
# Epoch 75/300
# 2/2 - 0s - loss: 0.0095 - mae: 0.0723 - val_loss: 0.0366 - val_mae: 0.1600
# Epoch 76/300
# 2/2 - 0s - loss: 0.0087 - mae: 0.0702 - val_loss: 0.0331 - val_mae: 0.1489
# Epoch 77/300
# 2/2 - 0s - loss: 0.0084 - mae: 0.0687 - val_loss: 0.0349 - val_mae: 0.1586
# Epoch 78/300
# 2/2 - 0s - loss: 0.0080 - mae: 0.0658 - val_loss: 0.0366 - val_mae: 0.1598
# Epoch 79/300
# 2/2 - 0s - loss: 0.0079 - mae: 0.0658 - val_loss: 0.0391 - val_mae: 0.1603
# Epoch 80/300
# 2/2 - 0s - loss: 0.0083 - mae: 0.0673 - val_loss: 0.0399 - val_mae: 0.1682
# Epoch 81/300
# 2/2 - 0s - loss: 0.0072 - mae: 0.0643 - val_loss: 0.0359 - val_mae: 0.1598
# Epoch 82/300
# 2/2 - 0s - loss: 0.0072 - mae: 0.0623 - val_loss: 0.0335 - val_mae: 0.1551
# Epoch 83/300
# 2/2 - 0s - loss: 0.0067 - mae: 0.0604 - val_loss: 0.0342 - val_mae: 0.1572
# Epoch 84/300
# 2/2 - 0s - loss: 0.0073 - mae: 0.0637 - val_loss: 0.0341 - val_mae: 0.1490
# Epoch 85/300
# 2/2 - 0s - loss: 0.0083 - mae: 0.0664 - val_loss: 0.0344 - val_mae: 0.1495
# Epoch 86/300
# 2/2 - 0s - loss: 0.0067 - mae: 0.0616 - val_loss: 0.0362 - val_mae: 0.1626
# Epoch 87/300
# 2/2 - 0s - loss: 0.0072 - mae: 0.0641 - val_loss: 0.0397 - val_mae: 0.1645
# Epoch 88/300
# 2/2 - 0s - loss: 0.0074 - mae: 0.0645 - val_loss: 0.0418 - val_mae: 0.1711
# Epoch 89/300
# 2/2 - 0s - loss: 0.0071 - mae: 0.0634 - val_loss: 0.0386 - val_mae: 0.1659
# Epoch 90/300
# 2/2 - 0s - loss: 0.0072 - mae: 0.0635 - val_loss: 0.0331 - val_mae: 0.1533
# Epoch 91/300
# 2/2 - 0s - loss: 0.0079 - mae: 0.0640 - val_loss: 0.0338 - val_mae: 0.1587
# Epoch 92/300
# 2/2 - 0s - loss: 0.0072 - mae: 0.0617 - val_loss: 0.0408 - val_mae: 0.1720
# Epoch 93/300
# 2/2 - 0s - loss: 0.0076 - mae: 0.0651 - val_loss: 0.0394 - val_mae: 0.1570
# Epoch 94/300
# 2/2 - 0s - loss: 0.0079 - mae: 0.0636 - val_loss: 0.0374 - val_mae: 0.1650
# Epoch 95/300
# 2/2 - 0s - loss: 0.0071 - mae: 0.0622 - val_loss: 0.0360 - val_mae: 0.1646
# Epoch 96/300
# 2/2 - 0s - loss: 0.0070 - mae: 0.0611 - val_loss: 0.0360 - val_mae: 0.1552
# Epoch 97/300
# 2/2 - 0s - loss: 0.0073 - mae: 0.0618 - val_loss: 0.0387 - val_mae: 0.1686
# Epoch 98/300
# 2/2 - 0s - loss: 0.0065 - mae: 0.0586 - val_loss: 0.0409 - val_mae: 0.1757
# Epoch 99/300
# 2/2 - 0s - loss: 0.0065 - mae: 0.0593 - val_loss: 0.0412 - val_mae: 0.1720
# Epoch 100/300
# 2/2 - 0s - loss: 0.0073 - mae: 0.0608 - val_loss: 0.0390 - val_mae: 0.1732
# Epoch 101/300
# 2/2 - 0s - loss: 0.0071 - mae: 0.0620 - val_loss: 0.0370 - val_mae: 0.1638
# Epoch 102/300
# 2/2 - 0s - loss: 0.0072 - mae: 0.0611 - val_loss: 0.0327 - val_mae: 0.1463
# Epoch 103/300
# 2/2 - 0s - loss: 0.0065 - mae: 0.0574 - val_loss: 0.0325 - val_mae: 0.1507
# Epoch 104/300
# 2/2 - 0s - loss: 0.0062 - mae: 0.0586 - val_loss: 0.0359 - val_mae: 0.1600
# Epoch 105/300
# 2/2 - 0s - loss: 0.0068 - mae: 0.0601 - val_loss: 0.0394 - val_mae: 0.1686
# Epoch 106/300
# 2/2 - 0s - loss: 0.0065 - mae: 0.0595 - val_loss: 0.0407 - val_mae: 0.1713
# Epoch 107/300
# 2/2 - 0s - loss: 0.0067 - mae: 0.0599 - val_loss: 0.0386 - val_mae: 0.1651
# Epoch 108/300
# 2/2 - 0s - loss: 0.0065 - mae: 0.0582 - val_loss: 0.0355 - val_mae: 0.1576
# Epoch 109/300
# 2/2 - 0s - loss: 0.0063 - mae: 0.0563 - val_loss: 0.0370 - val_mae: 0.1675
# Epoch 110/300
# 2/2 - 0s - loss: 0.0073 - mae: 0.0597 - val_loss: 0.0361 - val_mae: 0.1614
# Epoch 111/300
# 2/2 - 0s - loss: 0.0067 - mae: 0.0592 - val_loss: 0.0374 - val_mae: 0.1695
# Epoch 112/300
# 2/2 - 0s - loss: 0.0067 - mae: 0.0602 - val_loss: 0.0417 - val_mae: 0.1749
# Epoch 113/300
# 2/2 - 0s - loss: 0.0065 - mae: 0.0592 - val_loss: 0.0378 - val_mae: 0.1677
# Epoch 114/300
# 2/2 - 0s - loss: 0.0057 - mae: 0.0537 - val_loss: 0.0363 - val_mae: 0.1646
# Epoch 115/300
# 2/2 - 0s - loss: 0.0059 - mae: 0.0548 - val_loss: 0.0377 - val_mae: 0.1622
# Epoch 116/300
# 2/2 - 0s - loss: 0.0064 - mae: 0.0582 - val_loss: 0.0366 - val_mae: 0.1602
# Epoch 117/300
# 2/2 - 0s - loss: 0.0059 - mae: 0.0563 - val_loss: 0.0366 - val_mae: 0.1612
# Epoch 118/300
# 2/2 - 0s - loss: 0.0066 - mae: 0.0571 - val_loss: 0.0371 - val_mae: 0.1674
# Epoch 119/300
# 2/2 - 0s - loss: 0.0054 - mae: 0.0529 - val_loss: 0.0394 - val_mae: 0.1663
# Epoch 120/300
# 2/2 - 0s - loss: 0.0058 - mae: 0.0550 - val_loss: 0.0374 - val_mae: 0.1650
# Epoch 121/300
# 2/2 - 0s - loss: 0.0055 - mae: 0.0531 - val_loss: 0.0400 - val_mae: 0.1755
# Epoch 122/300
# 2/2 - 0s - loss: 0.0056 - mae: 0.0529 - val_loss: 0.0398 - val_mae: 0.1733
# Epoch 123/300
# 2/2 - 0s - loss: 0.0055 - mae: 0.0512 - val_loss: 0.0369 - val_mae: 0.1618
# Epoch 124/300
# 2/2 - 0s - loss: 0.0053 - mae: 0.0513 - val_loss: 0.0361 - val_mae: 0.1612
# Epoch 125/300
# 2/2 - 0s - loss: 0.0057 - mae: 0.0518 - val_loss: 0.0371 - val_mae: 0.1672
# Epoch 126/300
# 2/2 - 0s - loss: 0.0056 - mae: 0.0544 - val_loss: 0.0428 - val_mae: 0.1778
# Epoch 127/300
# 2/2 - 0s - loss: 0.0054 - mae: 0.0519 - val_loss: 0.0438 - val_mae: 0.1809
# Epoch 128/300
# 2/2 - 0s - loss: 0.0054 - mae: 0.0519 - val_loss: 0.0420 - val_mae: 0.1767
# Epoch 129/300
# 2/2 - 0s - loss: 0.0052 - mae: 0.0491 - val_loss: 0.0378 - val_mae: 0.1628
# Epoch 130/300
# 2/2 - 0s - loss: 0.0054 - mae: 0.0523 - val_loss: 0.0351 - val_mae: 0.1589
# Epoch 131/300
# 2/2 - 0s - loss: 0.0060 - mae: 0.0548 - val_loss: 0.0331 - val_mae: 0.1520
# Epoch 132/300
# 2/2 - 0s - loss: 0.0051 - mae: 0.0483 - val_loss: 0.0369 - val_mae: 0.1587
# Epoch 133/300
# 2/2 - 0s - loss: 0.0055 - mae: 0.0523 - val_loss: 0.0415 - val_mae: 0.1746
# Epoch 134/300
# 2/2 - 0s - loss: 0.0053 - mae: 0.0514 - val_loss: 0.0421 - val_mae: 0.1795
# Epoch 135/300
# 2/2 - 0s - loss: 0.0056 - mae: 0.0536 - val_loss: 0.0370 - val_mae: 0.1655
# Epoch 136/300
# 2/2 - 0s - loss: 0.0050 - mae: 0.0496 - val_loss: 0.0347 - val_mae: 0.1618
# Epoch 137/300
# 2/2 - 0s - loss: 0.0056 - mae: 0.0521 - val_loss: 0.0331 - val_mae: 0.1528
# Epoch 138/300
# 2/2 - 0s - loss: 0.0052 - mae: 0.0500 - val_loss: 0.0352 - val_mae: 0.1609
# Epoch 139/300
# 2/2 - 0s - loss: 0.0049 - mae: 0.0486 - val_loss: 0.0436 - val_mae: 0.1860
# Epoch 140/300
# 2/2 - 0s - loss: 0.0051 - mae: 0.0483 - val_loss: 0.0433 - val_mae: 0.1789
# Epoch 141/300
# 2/2 - 0s - loss: 0.0056 - mae: 0.0503 - val_loss: 0.0428 - val_mae: 0.1781
# Epoch 142/300
# 2/2 - 0s - loss: 0.0054 - mae: 0.0503 - val_loss: 0.0413 - val_mae: 0.1783
# Epoch 143/300
# 2/2 - 0s - loss: 0.0048 - mae: 0.0494 - val_loss: 0.0385 - val_mae: 0.1659
# Epoch 144/300
# 2/2 - 0s - loss: 0.0046 - mae: 0.0484 - val_loss: 0.0355 - val_mae: 0.1580
# Epoch 145/300
# 2/2 - 0s - loss: 0.0045 - mae: 0.0466 - val_loss: 0.0342 - val_mae: 0.1581
# Epoch 146/300
# 2/2 - 0s - loss: 0.0045 - mae: 0.0468 - val_loss: 0.0352 - val_mae: 0.1585
# Epoch 147/300
# 2/2 - 0s - loss: 0.0043 - mae: 0.0448 - val_loss: 0.0365 - val_mae: 0.1568
# Epoch 148/300
# 2/2 - 0s - loss: 0.0042 - mae: 0.0462 - val_loss: 0.0366 - val_mae: 0.1645
# Epoch 149/300
# 2/2 - 0s - loss: 0.0043 - mae: 0.0455 - val_loss: 0.0364 - val_mae: 0.1672
# Epoch 150/300
# 2/2 - 0s - loss: 0.0040 - mae: 0.0446 - val_loss: 0.0371 - val_mae: 0.1634
# Epoch 151/300
# 2/2 - 0s - loss: 0.0049 - mae: 0.0493 - val_loss: 0.0367 - val_mae: 0.1619
# Epoch 152/300
# 2/2 - 0s - loss: 0.0038 - mae: 0.0423 - val_loss: 0.0367 - val_mae: 0.1642
# Epoch 153/300
# 2/2 - 0s - loss: 0.0038 - mae: 0.0431 - val_loss: 0.0380 - val_mae: 0.1659
# Epoch 154/300
# 2/2 - 0s - loss: 0.0036 - mae: 0.0419 - val_loss: 0.0390 - val_mae: 0.1640
# Epoch 155/300
# 2/2 - 0s - loss: 0.0056 - mae: 0.0448 - val_loss: 0.0415 - val_mae: 0.1754
# Epoch 156/300
# 2/2 - 0s - loss: 0.0039 - mae: 0.0450 - val_loss: 0.0463 - val_mae: 0.1814
# Epoch 157/300
# 2/2 - 0s - loss: 0.0040 - mae: 0.0459 - val_loss: 0.0405 - val_mae: 0.1665
# Epoch 158/300
# 2/2 - 0s - loss: 0.0033 - mae: 0.0402 - val_loss: 0.0361 - val_mae: 0.1584
# Epoch 159/300
# 2/2 - 0s - loss: 0.0035 - mae: 0.0407 - val_loss: 0.0347 - val_mae: 0.1573
# Epoch 160/300
# 2/2 - 0s - loss: 0.0045 - mae: 0.0466 - val_loss: 0.0386 - val_mae: 0.1683
# Epoch 161/300
# 2/2 - 0s - loss: 0.0040 - mae: 0.0437 - val_loss: 0.0394 - val_mae: 0.1712
# Epoch 162/300
# 2/2 - 0s - loss: 0.0041 - mae: 0.0446 - val_loss: 0.0379 - val_mae: 0.1701
# Epoch 163/300
# 2/2 - 0s - loss: 0.0046 - mae: 0.0475 - val_loss: 0.0363 - val_mae: 0.1545
# Epoch 164/300
# 2/2 - 0s - loss: 0.0042 - mae: 0.0429 - val_loss: 0.0408 - val_mae: 0.1659
# Epoch 165/300
# 2/2 - 0s - loss: 0.0039 - mae: 0.0417 - val_loss: 0.0486 - val_mae: 0.1881
# Epoch 166/300
# 2/2 - 0s - loss: 0.0036 - mae: 0.0440 - val_loss: 0.0489 - val_mae: 0.1862
# Epoch 167/300
# 2/2 - 0s - loss: 0.0035 - mae: 0.0424 - val_loss: 0.0395 - val_mae: 0.1700
# Epoch 168/300
# 2/2 - 0s - loss: 0.0031 - mae: 0.0394 - val_loss: 0.0347 - val_mae: 0.1613
# Epoch 169/300
# 2/2 - 0s - loss: 0.0035 - mae: 0.0408 - val_loss: 0.0345 - val_mae: 0.1541
# Epoch 170/300
# 2/2 - 0s - loss: 0.0036 - mae: 0.0390 - val_loss: 0.0373 - val_mae: 0.1671
# Epoch 171/300
# 2/2 - 0s - loss: 0.0034 - mae: 0.0406 - val_loss: 0.0399 - val_mae: 0.1724
# Epoch 172/300
# 2/2 - 0s - loss: 0.0026 - mae: 0.0364 - val_loss: 0.0414 - val_mae: 0.1660
# Epoch 173/300
# 2/2 - 0s - loss: 0.0028 - mae: 0.0363 - val_loss: 0.0400 - val_mae: 0.1689
# Epoch 174/300
# 2/2 - 0s - loss: 0.0027 - mae: 0.0366 - val_loss: 0.0379 - val_mae: 0.1702
# Epoch 175/300
# 2/2 - 0s - loss: 0.0028 - mae: 0.0368 - val_loss: 0.0380 - val_mae: 0.1636
# Epoch 176/300
# 2/2 - 0s - loss: 0.0026 - mae: 0.0357 - val_loss: 0.0379 - val_mae: 0.1675
# Epoch 177/300
# 2/2 - 0s - loss: 0.0025 - mae: 0.0348 - val_loss: 0.0369 - val_mae: 0.1620
# Epoch 178/300
# 2/2 - 0s - loss: 0.0022 - mae: 0.0325 - val_loss: 0.0345 - val_mae: 0.1512
# Epoch 179/300
# 2/2 - 0s - loss: 0.0024 - mae: 0.0346 - val_loss: 0.0353 - val_mae: 0.1559
# Epoch 180/300
# 2/2 - 0s - loss: 0.0021 - mae: 0.0301 - val_loss: 0.0362 - val_mae: 0.1595
# Epoch 181/300
# 2/2 - 0s - loss: 0.0020 - mae: 0.0297 - val_loss: 0.0369 - val_mae: 0.1614
# Epoch 182/300
# 2/2 - 0s - loss: 0.0019 - mae: 0.0290 - val_loss: 0.0379 - val_mae: 0.1632
# Epoch 183/300
# 2/2 - 0s - loss: 0.0022 - mae: 0.0303 - val_loss: 0.0389 - val_mae: 0.1660
# Epoch 184/300
# 2/2 - 0s - loss: 0.0024 - mae: 0.0344 - val_loss: 0.0404 - val_mae: 0.1701
# Epoch 185/300
# 2/2 - 0s - loss: 0.0025 - mae: 0.0330 - val_loss: 0.0401 - val_mae: 0.1707
# Epoch 186/300
# 2/2 - 0s - loss: 0.0020 - mae: 0.0297 - val_loss: 0.0377 - val_mae: 0.1669
# Epoch 187/300
# 2/2 - 0s - loss: 0.0022 - mae: 0.0307 - val_loss: 0.0373 - val_mae: 0.1596
# Epoch 188/300
# 2/2 - 0s - loss: 0.0026 - mae: 0.0349 - val_loss: 0.0387 - val_mae: 0.1614
# Epoch 189/300
# 2/2 - 0s - loss: 0.0023 - mae: 0.0319 - val_loss: 0.0394 - val_mae: 0.1631
# Epoch 190/300
# 2/2 - 0s - loss: 0.0021 - mae: 0.0315 - val_loss: 0.0420 - val_mae: 0.1741
# Epoch 191/300
# 2/2 - 0s - loss: 0.0025 - mae: 0.0343 - val_loss: 0.0421 - val_mae: 0.1728
# Epoch 192/300
# 2/2 - 0s - loss: 0.0020 - mae: 0.0304 - val_loss: 0.0426 - val_mae: 0.1698
# Epoch 193/300
# 2/2 - 0s - loss: 0.0027 - mae: 0.0350 - val_loss: 0.0370 - val_mae: 0.1585
# Epoch 194/300
# 2/2 - 0s - loss: 0.0023 - mae: 0.0322 - val_loss: 0.0348 - val_mae: 0.1520
# Epoch 195/300
# 2/2 - 0s - loss: 0.0020 - mae: 0.0300 - val_loss: 0.0355 - val_mae: 0.1484
# Epoch 196/300
# 2/2 - 0s - loss: 0.0025 - mae: 0.0342 - val_loss: 0.0362 - val_mae: 0.1555
# Epoch 197/300
# 2/2 - 0s - loss: 0.0026 - mae: 0.0345 - val_loss: 0.0393 - val_mae: 0.1636
# Epoch 198/300
# 2/2 - 0s - loss: 0.0027 - mae: 0.0371 - val_loss: 0.0391 - val_mae: 0.1568
# Epoch 199/300
# 2/2 - 0s - loss: 0.0020 - mae: 0.0306 - val_loss: 0.0395 - val_mae: 0.1636
# Epoch 200/300
# 2/2 - 0s - loss: 0.0027 - mae: 0.0350 - val_loss: 0.0394 - val_mae: 0.1703
# Epoch 201/300
# 2/2 - 0s - loss: 0.0029 - mae: 0.0373 - val_loss: 0.0383 - val_mae: 0.1620
# Epoch 202/300
# 2/2 - 0s - loss: 0.0029 - mae: 0.0352 - val_loss: 0.0361 - val_mae: 0.1555
# Epoch 203/300
# 2/2 - 0s - loss: 0.0022 - mae: 0.0318 - val_loss: 0.0382 - val_mae: 0.1662
# Epoch 204/300
# 2/2 - 0s - loss: 0.0021 - mae: 0.0322 - val_loss: 0.0401 - val_mae: 0.1655
# Epoch 205/300
# 2/2 - 0s - loss: 0.0023 - mae: 0.0315 - val_loss: 0.0379 - val_mae: 0.1565
# Epoch 206/300
# 2/2 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0357 - val_mae: 0.1584
# Epoch 207/300
# 2/2 - 0s - loss: 0.0027 - mae: 0.0362 - val_loss: 0.0348 - val_mae: 0.1404
# Epoch 208/300
# 2/2 - 0s - loss: 0.0026 - mae: 0.0341 - val_loss: 0.0370 - val_mae: 0.1485
# Epoch 209/300
# 2/2 - 0s - loss: 0.0025 - mae: 0.0325 - val_loss: 0.0391 - val_mae: 0.1707
# Epoch 210/300
# 2/2 - 0s - loss: 0.0025 - mae: 0.0334 - val_loss: 0.0412 - val_mae: 0.1736
# Epoch 211/300
# 2/2 - 0s - loss: 0.0023 - mae: 0.0316 - val_loss: 0.0414 - val_mae: 0.1661
# Epoch 212/300
# 2/2 - 0s - loss: 0.0025 - mae: 0.0333 - val_loss: 0.0397 - val_mae: 0.1687
# Epoch 213/300
# 2/2 - 0s - loss: 0.0027 - mae: 0.0358 - val_loss: 0.0379 - val_mae: 0.1649
# Epoch 214/300
# 2/2 - 0s - loss: 0.0021 - mae: 0.0289 - val_loss: 0.0374 - val_mae: 0.1533
# Epoch 215/300
# 2/2 - 0s - loss: 0.0030 - mae: 0.0362 - val_loss: 0.0360 - val_mae: 0.1558
# Epoch 216/300
# 2/2 - 0s - loss: 0.0015 - mae: 0.0254 - val_loss: 0.0369 - val_mae: 0.1639
# Epoch 217/300
# 2/2 - 0s - loss: 0.0024 - mae: 0.0332 - val_loss: 0.0355 - val_mae: 0.1604
# Epoch 218/300
# 2/2 - 0s - loss: 0.0020 - mae: 0.0298 - val_loss: 0.0346 - val_mae: 0.1574
# Epoch 219/300
# 2/2 - 0s - loss: 0.0018 - mae: 0.0264 - val_loss: 0.0365 - val_mae: 0.1607
# Epoch 220/300
# 2/2 - 0s - loss: 0.0018 - mae: 0.0267 - val_loss: 0.0366 - val_mae: 0.1583
# Epoch 221/300
# 2/2 - 0s - loss: 0.0015 - mae: 0.0247 - val_loss: 0.0377 - val_mae: 0.1591
# Epoch 222/300
# 2/2 - 0s - loss: 0.0018 - mae: 0.0280 - val_loss: 0.0376 - val_mae: 0.1645
# Epoch 223/300
# 2/2 - 0s - loss: 0.0020 - mae: 0.0281 - val_loss: 0.0397 - val_mae: 0.1664
# Epoch 224/300
# 2/2 - 0s - loss: 0.0017 - mae: 0.0276 - val_loss: 0.0415 - val_mae: 0.1689
# Epoch 225/300
# 2/2 - 0s - loss: 0.0018 - mae: 0.0274 - val_loss: 0.0423 - val_mae: 0.1717
# Epoch 226/300
# 2/2 - 0s - loss: 0.0015 - mae: 0.0245 - val_loss: 0.0418 - val_mae: 0.1693
# Epoch 227/300
# 2/2 - 0s - loss: 0.0016 - mae: 0.0241 - val_loss: 0.0419 - val_mae: 0.1704
# Epoch 228/300
# 2/2 - 0s - loss: 0.0021 - mae: 0.0303 - val_loss: 0.0410 - val_mae: 0.1725
# Epoch 229/300
# 2/2 - 0s - loss: 0.0019 - mae: 0.0302 - val_loss: 0.0406 - val_mae: 0.1719
# Epoch 230/300
# 2/2 - 0s - loss: 0.0019 - mae: 0.0291 - val_loss: 0.0432 - val_mae: 0.1645
# Epoch 231/300
# 2/2 - 0s - loss: 0.0029 - mae: 0.0388 - val_loss: 0.0412 - val_mae: 0.1702
# Epoch 232/300
# 2/2 - 0s - loss: 0.0022 - mae: 0.0310 - val_loss: 0.0396 - val_mae: 0.1745
# Epoch 233/300
# 2/2 - 0s - loss: 0.0026 - mae: 0.0359 - val_loss: 0.0382 - val_mae: 0.1655
# Epoch 234/300
# 2/2 - 0s - loss: 0.0031 - mae: 0.0364 - val_loss: 0.0408 - val_mae: 0.1689
# Epoch 235/300
# 2/2 - 0s - loss: 0.0021 - mae: 0.0291 - val_loss: 0.0423 - val_mae: 0.1793
# Epoch 236/300
# 2/2 - 0s - loss: 0.0024 - mae: 0.0346 - val_loss: 0.0380 - val_mae: 0.1563
# Epoch 237/300
# 2/2 - 0s - loss: 0.0018 - mae: 0.0261 - val_loss: 0.0408 - val_mae: 0.1646
# Epoch 238/300
# 2/2 - 0s - loss: 0.0021 - mae: 0.0284 - val_loss: 0.0483 - val_mae: 0.1884
# Epoch 239/300
# 2/2 - 0s - loss: 0.0026 - mae: 0.0354 - val_loss: 0.0457 - val_mae: 0.1837
# Epoch 240/300
# 2/2 - 0s - loss: 0.0017 - mae: 0.0272 - val_loss: 0.0433 - val_mae: 0.1743
# Epoch 241/300
# 2/2 - 0s - loss: 0.0022 - mae: 0.0306 - val_loss: 0.0440 - val_mae: 0.1780
# Epoch 242/300
# 2/2 - 0s - loss: 0.0018 - mae: 0.0288 - val_loss: 0.0422 - val_mae: 0.1710
# Epoch 243/300
# 2/2 - 0s - loss: 0.0014 - mae: 0.0231 - val_loss: 0.0391 - val_mae: 0.1607
# Epoch 244/300
# 2/2 - 0s - loss: 0.0022 - mae: 0.0295 - val_loss: 0.0366 - val_mae: 0.1625
# Epoch 245/300
# 2/2 - 0s - loss: 0.0015 - mae: 0.0252 - val_loss: 0.0372 - val_mae: 0.1628
# Epoch 246/300
# 2/2 - 0s - loss: 0.0017 - mae: 0.0271 - val_loss: 0.0380 - val_mae: 0.1553
# Epoch 247/300
# 2/2 - 0s - loss: 0.0021 - mae: 0.0302 - val_loss: 0.0382 - val_mae: 0.1596
# Epoch 248/300
# 2/2 - 0s - loss: 0.0018 - mae: 0.0282 - val_loss: 0.0380 - val_mae: 0.1611
# Epoch 249/300
# 2/2 - 0s - loss: 0.0015 - mae: 0.0254 - val_loss: 0.0349 - val_mae: 0.1535
# Epoch 250/300
# 2/2 - 0s - loss: 0.0022 - mae: 0.0310 - val_loss: 0.0346 - val_mae: 0.1559
# Epoch 251/300
# 2/2 - 0s - loss: 0.0022 - mae: 0.0301 - val_loss: 0.0391 - val_mae: 0.1695
# Epoch 252/300
# 2/2 - 0s - loss: 0.0025 - mae: 0.0330 - val_loss: 0.0406 - val_mae: 0.1696
# Epoch 253/300
# 2/2 - 0s - loss: 0.0015 - mae: 0.0250 - val_loss: 0.0431 - val_mae: 0.1735
# Epoch 254/300
# 2/2 - 0s - loss: 0.0021 - mae: 0.0312 - val_loss: 0.0428 - val_mae: 0.1783
# Epoch 255/300
# 2/2 - 0s - loss: 0.0017 - mae: 0.0262 - val_loss: 0.0407 - val_mae: 0.1724
# Epoch 256/300
# 2/2 - 0s - loss: 0.0024 - mae: 0.0326 - val_loss: 0.0393 - val_mae: 0.1678
# Epoch 257/300
# 2/2 - 0s - loss: 0.0019 - mae: 0.0274 - val_loss: 0.0401 - val_mae: 0.1668
# Epoch 258/300
# 2/2 - 0s - loss: 0.0022 - mae: 0.0316 - val_loss: 0.0393 - val_mae: 0.1667
# Epoch 259/300
# 2/2 - 0s - loss: 0.0020 - mae: 0.0286 - val_loss: 0.0378 - val_mae: 0.1621
# Epoch 260/300
# 2/2 - 0s - loss: 0.0018 - mae: 0.0263 - val_loss: 0.0382 - val_mae: 0.1651
# Epoch 261/300
# 2/2 - 0s - loss: 0.0019 - mae: 0.0286 - val_loss: 0.0417 - val_mae: 0.1673
# Epoch 262/300
# 2/2 - 0s - loss: 0.0017 - mae: 0.0269 - val_loss: 0.0424 - val_mae: 0.1656
# Epoch 263/300
# 2/2 - 0s - loss: 0.0015 - mae: 0.0251 - val_loss: 0.0421 - val_mae: 0.1675
# Epoch 264/300
# 2/2 - 0s - loss: 0.0012 - mae: 0.0227 - val_loss: 0.0416 - val_mae: 0.1715
# Epoch 265/300
# 2/2 - 0s - loss: 0.0015 - mae: 0.0245 - val_loss: 0.0407 - val_mae: 0.1704
# Epoch 266/300
# 2/2 - 0s - loss: 0.0014 - mae: 0.0233 - val_loss: 0.0399 - val_mae: 0.1672
# Epoch 267/300
# 2/2 - 0s - loss: 0.0016 - mae: 0.0249 - val_loss: 0.0400 - val_mae: 0.1701
# Epoch 268/300
# 2/2 - 0s - loss: 0.0014 - mae: 0.0228 - val_loss: 0.0409 - val_mae: 0.1740
# Epoch 269/300
# 2/2 - 0s - loss: 0.0018 - mae: 0.0282 - val_loss: 0.0419 - val_mae: 0.1700
# Epoch 270/300
# 2/2 - 0s - loss: 0.0013 - mae: 0.0224 - val_loss: 0.0402 - val_mae: 0.1654
# Epoch 271/300
# 2/2 - 0s - loss: 0.0015 - mae: 0.0235 - val_loss: 0.0372 - val_mae: 0.1587
# Epoch 272/300
# 2/2 - 0s - loss: 0.0013 - mae: 0.0223 - val_loss: 0.0345 - val_mae: 0.1544
# Epoch 273/300
# 2/2 - 0s - loss: 0.0013 - mae: 0.0212 - val_loss: 0.0344 - val_mae: 0.1544
# Epoch 274/300
# 2/2 - 0s - loss: 0.0013 - mae: 0.0211 - val_loss: 0.0371 - val_mae: 0.1585
# Epoch 275/300
# 2/2 - 0s - loss: 0.0014 - mae: 0.0227 - val_loss: 0.0392 - val_mae: 0.1622
# Epoch 276/300
# 2/2 - 0s - loss: 0.0015 - mae: 0.0234 - val_loss: 0.0396 - val_mae: 0.1609
# Epoch 277/300
# 2/2 - 0s - loss: 0.0015 - mae: 0.0238 - val_loss: 0.0398 - val_mae: 0.1647
# Epoch 278/300
# 2/2 - 0s - loss: 0.0013 - mae: 0.0214 - val_loss: 0.0394 - val_mae: 0.1666
# Epoch 279/300
# 2/2 - 0s - loss: 0.0013 - mae: 0.0226 - val_loss: 0.0385 - val_mae: 0.1643
# Epoch 280/300
# 2/2 - 0s - loss: 0.0014 - mae: 0.0231 - val_loss: 0.0382 - val_mae: 0.1620
# Epoch 281/300
# 2/2 - 0s - loss: 0.0016 - mae: 0.0252 - val_loss: 0.0385 - val_mae: 0.1650
# Epoch 282/300
# 2/2 - 0s - loss: 0.0014 - mae: 0.0249 - val_loss: 0.0384 - val_mae: 0.1612
# Epoch 283/300
# 2/2 - 0s - loss: 0.0017 - mae: 0.0261 - val_loss: 0.0401 - val_mae: 0.1648
# Epoch 284/300
# 2/2 - 0s - loss: 0.0014 - mae: 0.0225 - val_loss: 0.0409 - val_mae: 0.1710
# Epoch 285/300
# 2/2 - 0s - loss: 0.0017 - mae: 0.0261 - val_loss: 0.0425 - val_mae: 0.1745
# Epoch 286/300
# 2/2 - 0s - loss: 0.0017 - mae: 0.0260 - val_loss: 0.0451 - val_mae: 0.1776
# Epoch 287/300
# 2/2 - 0s - loss: 0.0013 - mae: 0.0236 - val_loss: 0.0441 - val_mae: 0.1779
# Epoch 288/300
# 2/2 - 0s - loss: 0.0019 - mae: 0.0278 - val_loss: 0.0418 - val_mae: 0.1783
# Epoch 289/300
# 2/2 - 0s - loss: 0.0014 - mae: 0.0231 - val_loss: 0.0400 - val_mae: 0.1735
# Epoch 290/300
# 2/2 - 0s - loss: 0.0016 - mae: 0.0255 - val_loss: 0.0403 - val_mae: 0.1687
# Epoch 291/300
# 2/2 - 0s - loss: 0.0012 - mae: 0.0204 - val_loss: 0.0413 - val_mae: 0.1689
# Epoch 292/300
# 2/2 - 0s - loss: 0.0013 - mae: 0.0222 - val_loss: 0.0409 - val_mae: 0.1672
# Epoch 293/300
# 2/2 - 0s - loss: 0.0016 - mae: 0.0242 - val_loss: 0.0401 - val_mae: 0.1656
# Epoch 294/300
# 2/2 - 0s - loss: 0.0014 - mae: 0.0210 - val_loss: 0.0380 - val_mae: 0.1626
# Epoch 295/300
# 2/2 - 0s - loss: 0.0016 - mae: 0.0255 - val_loss: 0.0372 - val_mae: 0.1578
# Epoch 296/300
# 2/2 - 0s - loss: 0.0014 - mae: 0.0228 - val_loss: 0.0375 - val_mae: 0.1592
# Epoch 297/300
# 2/2 - 0s - loss: 0.0013 - mae: 0.0220 - val_loss: 0.0377 - val_mae: 0.1618
# Epoch 298/300
# 2/2 - 0s - loss: 0.0011 - mae: 0.0189 - val_loss: 0.0373 - val_mae: 0.1611
# Epoch 299/300
# 2/2 - 0s - loss: 0.0014 - mae: 0.0231 - val_loss: 0.0365 - val_mae: 0.1644
# Epoch 300/300
# 2/2 - 0s - loss: 0.0016 - mae: 0.0243 - val_loss: 0.0371 - val_mae: 0.1607

# %%
# Grafik training dan validation loss
training_loss=fitting_history.history['loss']
validation_loss=fitting_history.history['val_loss']
epochs=range(len(training_loss))

plt.plot(epochs, training_loss, 'r', label="Training Loss")
plt.plot(epochs, validation_loss, 'b', label="Validation Loss")
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.figure()

# %%
# Grafik training and validation MAE
training_mae=fitting_history.history['mae']
validation_mae=fitting_history.history['val_mae']
epochs=range(len(training_mae))

plt.plot(epochs, training_mae, 'r', label="Training MAE")
plt.plot(epochs, validation_mae, 'b', label="Validation MAE")
plt.title('Training and validation MAE')
plt.legend(loc=0)
plt.figure()

# %%
# Menghitung nilai MSE dan MAE
mse_score, mae_score = model.evaluate(input_test, output_test)
print('Nilai Mean Squared Error (MSE) : ', mse_score)
print('Nilai Mean Absolute Error (MAE) : ', mae_score)
# Out:
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1722 - mae: 0.3397
# Nilai Mean Squared Error (MSE) :  0.17221717536449432
# Nilai Mean Absolute Error (MAE) :  0.33974048495292664

# %%
# Simpan model
model.save('model-curahhujan.h5')

# %% [markdown]
# # **Testing Model**

# %%
# Load the model
model = tf.keras.models.load_model('model-curahhujan.h5')

# %%
#Prediksi Data
data_prediksi = model.predict(input_test)

# %%
print(data_prediksi)
print("-------")
print(output_test)
# Out:
# [[0.14182805 0.10079049 0.19803017 0.02796401]
#  [0.         0.01955914 0.         0.05335794]
#  [0.         0.02132033 0.         0.2873808 ]
#  [0.         0.07267055 0.3165413  0.59941876]
#  [0.38488957 0.6591871  0.4415036  0.80754375]
#  [0.5339905  0.4612581  0.8963321  0.7213673 ]
#  [0.41266167 0.940054   0.6311908  0.27287614]]
# -------
# [[0.03581604 0.         0.08099308 0.27269027]
#  [0.         0.08099308 0.27269027 0.88888889]
#  [0.08099308 0.27269027 0.88888889 0.8021978 ]
#  [0.27269027 0.88888889 0.8021978  0.67806268]
#  [0.88888889 0.8021978  0.67806268 0.38054538]
#  [0.8021978  0.67806268 0.38054538 0.18030118]
#  [0.67806268 0.38054538 0.18030118 0.01587302]]

# %%
# Inverse transform data min max
data_prediksi = scaler.inverse_transform(data_prediksi)
output_test = scaler.inverse_transform(output_test)

# %%
print(data_prediksi)
print("-------")
print(output_test)
# Out:
# [[ 3.484715    2.4764223   4.8656015   0.68707573]
#  [ 0.          0.4805682   0.          1.3110046 ]
#  [ 0.          0.5238405   0.          7.0609465 ]
#  [ 0.          1.7855154   7.77742    14.727719  ]
#  [ 9.456737   16.196226   10.847744   19.84135   ]
#  [13.120147   11.333112   22.022879   17.723995  ]
#  [10.139097   23.097126   15.508357    6.704567  ]]
# -------
# [[ 0.88  0.    1.99  6.7 ]
#  [ 0.    1.99  6.7  21.84]
#  [ 1.99  6.7  21.84 19.71]
#  [ 6.7  21.84 19.71 16.66]
#  [21.84 19.71 16.66  9.35]
#  [19.71 16.66  9.35  4.43]
#  [16.66  9.35  4.43  0.39]]

# %%
temp_test=[]
number=[]
count=1

for j in output_test[0]:
  temp_test.append(j)
  number.append(count)
  count+=1
  
print(temp_test)
print(number)

temp_predict=[]
number=[]
count=1

for j in data_prediksi[0]:
  temp_predict.append(j)
  number.append(count)
  count+=1
  
print(temp_predict)
print(number)

# Grafik garis dari Suhu
plt.plot(number,temp_predict,marker='o',color="yellow")
plt.plot(number,temp_test,marker='o',color="black")
plt.title('Curah Hujan')
plt.ylabel('mm')
plt.xlabel('Bulan')
plt.show()
# Out:
# [0.8800000000000001, 0.0, 1.99, 6.7]
# [1, 2, 3, 4]
# [3.484715, 2.4764223, 4.8656015, 0.68707573]
# [1, 2, 3, 4]

# %%
temp_test=[]
number=[]
count=1

for j in output_test[1]:
  temp_test.append(j)
  number.append(count)
  count+=1
  
print(temp_test)
print(number)

temp_predict=[]
number=[]
count=1

for j in data_prediksi[1]:
  temp_predict.append(j)
  number.append(count)
  count+=1
  
print(temp_predict)
print(number)

# Grafik garis dari Suhu
plt.plot(number,temp_predict,marker='o',color="yellow")
plt.plot(number,temp_test,marker='o',color="black")
plt.title('Curah Hujan')
plt.ylabel('mm')
plt.xlabel('Bulan')
plt.show()
# Out:
# [0.0, 1.99, 6.7, 21.84]
# [1, 2, 3, 4]
# [0.0, 0.4805682, 0.0, 1.3110046]
# [1, 2, 3, 4]

# %%
temp_test=[]
number=[]
count=1

for j in output_test[2]:
  temp_test.append(j)
  number.append(count)
  count+=1
  
print(temp_test)
print(number)

temp_predict=[]
number=[]
count=1

for j in data_prediksi[2]:
  temp_predict.append(j)
  number.append(count)
  count+=1
  
print(temp_predict)
print(number)

# Grafik garis dari Suhu
plt.plot(number,temp_predict,marker='o',color="yellow")
plt.plot(number,temp_test,marker='o',color="black")
plt.title('Curah Hujan')
plt.ylabel('mm')
plt.xlabel('Bulan')
plt.show()
# Out:
# [1.99, 6.7, 21.84, 19.71]
# [1, 2, 3, 4]
# [0.0, 0.5238405, 0.0, 7.0609465]
# [1, 2, 3, 4]

# %%
temp_test=[]
number=[]
count=1

for j in output_test[3]:
  temp_test.append(j)
  number.append(count)
  count+=1
  
print(temp_test)
print(number)

temp_predict=[]
number=[]
count=1

for j in data_prediksi[3]:
  temp_predict.append(j)
  number.append(count)
  count+=1
  
print(temp_predict)
print(number)

# Grafik garis dari Suhu
plt.plot(number,temp_predict,marker='o',color="yellow")
plt.plot(number,temp_test,marker='o',color="black")
plt.title('Curah Hujan')
plt.ylabel('mm')
plt.xlabel('Bulan')
plt.show()
# Out:
# [6.7, 21.84, 19.71, 16.66]
# [1, 2, 3, 4]
# [0.0, 1.7855154, 7.77742, 14.727719]
# [1, 2, 3, 4]

# %%
temp_test=[]
number=[]
count=1

for j in output_test[4]:
  temp_test.append(j)
  number.append(count)
  count+=1
  
print(temp_test)
print(number)

temp_predict=[]
number=[]
count=1

for j in data_prediksi[4]:
  temp_predict.append(j)
  number.append(count)
  count+=1
  
print(temp_predict)
print(number)

# Grafik garis dari Suhu
plt.plot(number,temp_predict,marker='o',color="yellow")
plt.plot(number,temp_test,marker='o',color="black")
plt.title('Curah Hujan')
plt.ylabel('mm')
plt.xlabel('Bulan')
plt.show()
# Out:
# [21.84, 19.71, 16.66, 9.35]
# [1, 2, 3, 4]
# [9.456737, 16.196226, 10.847744, 19.84135]
# [1, 2, 3, 4]

# %%
temp_test=[]
number=[]
count=1

for j in output_test[5]:
  temp_test.append(j)
  number.append(count)
  count+=1
  
print(temp_test)
print(number)

temp_predict=[]
number=[]
count=1

for j in data_prediksi[5]:
  temp_predict.append(j)
  number.append(count)
  count+=1
  
print(temp_predict)
print(number)

# Grafik garis dari Suhu
plt.plot(number,temp_predict,marker='o',color="yellow")
plt.plot(number,temp_test,marker='o',color="black")
plt.title('Curah Hujan')
plt.ylabel('mm')
plt.xlabel('Bulan')
plt.show()
# Out:
# [19.71, 16.66, 9.35, 4.43]
# [1, 2, 3, 4]
# [13.120147, 11.333112, 22.022879, 17.723995]
# [1, 2, 3, 4]

# %%
temp_test=[]
number=[]
count=1

for j in output_test[6]:
  temp_test.append(j)
  number.append(count)
  count+=1
  
print(temp_test)
print(number)

temp_predict=[]
number=[]
count=1

for j in data_prediksi[6]:
  temp_predict.append(j)
  number.append(count)
  count+=1
  
print(temp_predict)
print(number)

# Grafik garis dari Suhu
plt.plot(number,temp_predict,marker='o',color="yellow")
plt.plot(number,temp_test,marker='o',color="black")
plt.title('Curah Hujan')
plt.ylabel('mm')
plt.xlabel('Bulan')
plt.show()
# Out:
# [16.66, 9.35, 4.43, 0.39]
# [1, 2, 3, 4]
# [10.139097, 23.097126, 15.508357, 6.704567]
# [1, 2, 3, 4]
